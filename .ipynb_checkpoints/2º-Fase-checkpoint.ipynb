# %% [markdown]
# # <font color='blue'>Data Science Challenge @ ITA 2022</font>
# # <font color='blue'>Equipe DIOMGIS</font>
#
# ## <font color='blue'>2º Fase</font>
#
# ### <font color='blue'>Construção de carteira composta por ativos que compõem o índice SP500.</font>

# %% [markdown]
# ![title](data\image\logo.jpeg)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.12

# %%
# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# Bibliotecas e Frameworks

import numpy as np
import pandas as pd
import pandas_datareader.data as web

from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
from datetime import datetime
from hurst import compute_Hc, random_walk
from pykalman import KalmanFilter
from statsmodels.tsa.seasonal import STL

from sklearn.cluster import KMeans

# %%
# Versões dos pacotes usados neste jupyter notebook

# %reload_ext watermark
# %watermark -a "Equipe DIOMGIS" --iversions
# Out:
# Author: Equipe DIOMGIS
#
# matplotlib       : 3.5.1
# seaborn          : 0.11.2
# numpy            : 1.22.3
# pandas           : 1.4.2
# pandas_datareader: 0.10.0

# %%
# %matplotlib inline
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
plt.rcParams['figure.figsize'] = (15, 10)

# %%
# Parametros fixos de treinamento

quantAtivos = 10
verbose = 2
seed = 25
epochs = 2000
downloadData = False

np.random.seed(seed)

# %%
setores = {
    'Industrials': ['MMM', 'AOS', 'ALK', 'ALLE', 'AAL', 'AME', 'BA',
                    'CHRW', 'CARR', 'CAT', 'CTAS', 'CPRT', 'CSGP',
                    'CSX', 'CMI', 'DE', 'DAL', 'DOV', 'ETN', 'EMR',
                    'EFX', 'EXPD', 'FAST', 'FDX', 'FTV', 'FBHS',
                    'GNRC', 'GD', 'GE', 'HON', 'HWM', 'HII', 'IEX',
                    'ITW', 'IR', 'JBHT', 'J', 'JCI', 'LHX', 'LDOS',
                    'LMT', 'MAS', 'NDSN', 'NSC', 'NOC', 'ODFL',
                    'OTIS', 'PCAR', 'PH', 'PNR', 'PWR', 'RTX', 'RSG',
                    'RHI', 'ROK', 'ROL', 'SNA', 'LUV', 'SWK', 'TXT',
                    'TT', 'TDG', 'UNP', 'UAL', 'UPS', 'URI', 'VRSK',
                    'WAB', 'WM', 'GWW', 'XYL'],
    
    'HealthCare': ['ABT', 'ABBV', 'ABMD', 'A', 'ALGN', 'ABC', 'AMGN',
                   'BAX', 'BDX', 'BIO', 'TECH', 'BIIB', 'BSX', 'BMY',
                   'CAH', 'CTLT', 'CNC', 'CRL', 'CI', 'COO', 'CVS',
                   'DHR', 'DVA', 'XRAY', 'DXCM', 'EW', 'ELV', 'LLY',
                   'GILD', 'HCA', 'HSIC', 'HOLX', 'HUM', 'IDXX',
                   'ILMN', 'INCY', 'ISRG', 'IQV', 'JNJ', 'LH', 'MCK',
                   'MDT', 'MRK', 'MTD', 'MRNA', 'MOH', 'OGN', 'PKI',
                   'PFE', 'DGX', 'REGN', 'RMD', 'STE', 'SYK', 'TFX',
                   'TMO', 'UNH', 'UHS', 'VRTX', 'VTRS', 'WAT',
                   'WST', 'ZBH', 'ZTS'],
    
    'InformationTechnology': ['ACN', 'ADBE', 'ADP', 'AKAM', 'AMD', 'APH',
                              'ADI', 'ANSS', 'AAPL', 'AMAT', 'ANET', 'ADSK',
                              'AVGO', 'BR', 'CDNS', 'CDW', 'CDAY', 'CSCO',
                              'CTSH', 'GLW', 'DXC', 'ENPH', 'EPAM', 'FFIV',
                              'FIS', 'FISV', 'FLT', 'FTNT', 'IT', 'GPN',
                              'HPE', 'HPQ', 'IBM', 'INTC', 'INTU', 'JKHY',
                              'JNPR', 'KEYS', 'KLAC', 'LRCX', 'MA', 'MCHP',
                              'MU', 'MSFT', 'MPWR', 'MSI', 'NTAP', 'NLOK',
                              'NVDA', 'NXPI', 'ON', 'ORCL', 'PAYX', 'PAYC',
                              'PYPL', 'PTC', 'QRVO', 'QCOM', 'ROP', 'CRM',
                              'STX', 'NOW', 'SWKS', 'SEDG', 'SNPS', 'TEL',
                              'TDY', 'TER', 'TXN', 'TRMB', 'TYL', 'VRSN',
                              'V', 'WDC', 'ZBRA'],
    
    'CommunicationServices': ['ATVI', 'GOOGL', 'GOOG', 'T', 'CHTR', 'CMCSA',
                              'DISH', 'DIS', 'EA', 'FOXA', 'FOX', 'IPG', 'LYV',
                              'LUMN', 'MTCH', 'META', 'NFLX', 'NWSA', 'NWS',
                              'OMC', 'PARA', 'TMUS', 'TTWO', 'TWTR', 'VZ', 'WBD'],
    
    'ConsumerStaples': ['ADM', 'MO', 'BF.B', 'CPB', 'CHD', 'CLX', 'KO', 'CL',
                        'CAG', 'STZ', 'COST', 'EL', 'GIS', 'HSY', 'HRL', 'K',
                        'KDP', 'KMB', 'KHC', 'KR', 'LW', 'MKC', 'TAP', 'MDLZ',
                        'MNST', 'PEP', 'PM', 'PG', 'SJM', 'SYY', 'TSN', 'WBA',
                        'WMT'],
    
    'ConsumerDiscretionary': ['AAP', 'AMZN', 'APTV', 'AZO', 'BBWI',
                              'BBY', 'BKNG', 'BWA', 'CZR', 'KMX', 'CCL',
                              'CMG', 'DHI', 'DRI', 'DG', 'DLTR',
                              'DPZ', 'EBAY', 'ETSY', 'EXPE', 'F',
                              'GRMN', 'GM', 'GPC', 'HAS', 'HLT', 'HD',
                              'LVS', 'LEN', 'LKQ', 'LOW', 'MAR', 'MCD',
                              'MGM', 'MHK', 'NWL', 'NKE', 'NCLH', 'NVR',
                              'ORLY', 'POOL', 'PHM', 'RL', 'ROST', 'RCL',
                              'SBUX', 'TPR', 'TGT', 'TSLA', 'TJX',
                              'TSCO', 'ULTA', 'VFC', 'WHR', 'WYNN', 'YUM'],
    
    'Utilities': ['AES', 'LNT', 'AEE', 'AEP', 'AWK', 'ATO', 'CNP',
                  'CMS', 'ED', 'CEG', 'D', 'DTE', 'DUK', 'EIX',
                  'ETR', 'EVRG', 'ES', 'EXC', 'FE', 'NEE', 'NI',
                  'NRG', 'PCG', 'PNW', 'PPL', 'PEG', 'SRE', 'SO',
                  'WEC', 'XEL'],
    
    'Financials': ['AFL', 'ALL', 'AXP', 'AIG', 'AMP', 'AON', 'AJG',
                   'AIZ', 'BAC', 'WRB', 'BRK.B', 'BLK', 'BK', 'BRO',
                   'COF', 'CBOE', 'SCHW', 'CB', 'CINF', 'C', 'CFG',
                   'CME', 'CMA', 'DFS', 'RE', 'FDS', 'FITB', 'FRC',
                   'BEN', 'GL', 'GS', 'HIG', 'HBAN', 'ICE', 'IVZ',
                   'JPM', 'KEY', 'LNC', 'L', 'MTB', 'MKTX', 'MMC',
                   'MET', 'MCO', 'MS', 'MSCI', 'NDAQ', 'NTRS', 'PNC',
                   'PFG', 'PGR', 'PRU', 'RJF', 'RF', 'SPGI', 'SBNY',
                   'STT', 'SIVB', 'SYF', 'TROW', 'TRV', 'TFC',
                   'USB', 'WFC', 'WTW', 'ZION',  'NLSN'],
    
    'Materials': ['APD', 'ALB', 'AMCR', 'AVY', 'BALL', 'CE', 'CF',
                  'CTVA', 'DOW', 'DD', 'EMN', 'ECL', 'FMC', 'FCX',
                  'IP', 'IFF', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM',
                  'NUE', 'PKG', 'PPG', 'SEE', 'SHW', 'VMC', 'WRK'],
    
    'RealEstate': ['ARE', 'AMT', 'AVB', 'BXP', 'CPT', 'CBRE', 'CCI',
                   'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'PEAK',
                   'HST', 'INVH', 'IRM', 'KIM', 'MAA', 'PLD', 'PSA',
                   'O', 'REG', 'SBAC', 'SPG', 'UDR', 'VTR', 'VICI',
                   'VNO', 'WELL', 'WY'],
    
    'Energy': ['APA','BKR', 'CVX', 'COP', 'CTRA', 'DVN', 'FANG', 'EOG',
               'EQT', 'XOM', 'HAL', 'HES', 'KMI', 'MRO', 'MPC', 'OXY',
               'OKE', 'PSX', 'PXD', 'SLB', 'VLO', 'WMB']
}

# %%
ativos = []
for setor, empresas in setores.items():
    ativos.extend(empresas)
    
ativos.sort()

# %% [markdown]
# ### Download dos Dados

# %%
if downloadData:

    start_date = "2017-10-21"
    end_date = "2022-10-21"

    data = web.DataReader(name = '^GSPC', data_source = 'yahoo', start = start_date, end = end_date)
    SP500_index = pd.DataFrame(data['Close']).reset_index().rename(columns={'Close': 'SP500', 'Date': 'Dia'})

    SP500_close = pd.DataFrame()

    for ativo in ativos:
  
        if ativo == 'BF.B':
            ativo = 'BF-B'

        if ativo == 'BRK.B':
            ativo = 'BRK-B'

        data = web.DataReader(name = ativo, data_source = 'yahoo', start = start_date, end = end_date)
        temp_close = pd.DataFrame(data['Close'])
        SP500_close = pd.concat([SP500_close, temp_close], axis = 1)

        
    SP500_close.columns = ativos
    SP500_close.reset_index(inplace = True)
    SP500_close.rename(columns={'Date': 'Dia'}, inplace = True)

    outdir = './data/{}-{}'.format(start_date, end_date)

    if not os.path.exists(outdir):
        os.mkdir(outdir)
    
    SP500_close.to_csv(path_or_buf = os.path.join(outdir, 'SP500_close'), index = False)
    SP500_index.to_csv(path_or_buf = os.path.join(outdir, 'SP500_index'), index = False)
    
else:
    SP500_close = pd.read_csv('./data/train/SP500Close.csv')
    SP500_close = SP500_close.set_index("Dia")
    SP500_close.index = pd.to_datetime(SP500_close.index)
    SP500_index = pd.read_csv('./data/train/SP500Index.csv')
    SP500_index = SP500_index.set_index("Dia")
    SP500_index.index = pd.to_datetime(SP500_index.index)

# %% [markdown]
# ## Pré-Processamento dos Dados

# %%
df = SP500_close.copy()

# %%
df.isna().any().sum()
# Out:
# 11

# %%
df = df.fillna(method = 'backfill', axis = 'columns')

# %%
df.isna().any().sum()
# Out:
# 0

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler()

# %%
dfScalerNP = scaler.transform(df)

# %%
dfScaled = pd.DataFrame(dfScalerNP, columns = df.columns, index = df.index)

# %%
df.T.sample(3, random_state = 11).T.plot();

# %%
dfScaled.T.sample(3, random_state = 11).T.plot();

# %%
kmeans = KMeans(n_clusters = quantAtivos,
                n_init = 10 ,
                max_iter = 300,
                tol = 0.0001,
                verbose = 2,
                random_state = seed,
                algorithm = 'lloyd') # “lloyd”, “elkan”

# %%
kmeans.fit(dfScalerNP.T)
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Initialization complete
# Iteration 0, inertia 173199.27417193388.
# Iteration 1, inertia 129409.72858524085.
# Iteration 2, inertia 124747.82396122783.
# Iteration 3, inertia 122603.19738551763.
# Iteration 4, inertia 121128.32120678114.
# Iteration 5, inertia 120564.45592987907.
# Iteration 6, inertia 119989.42465453116.
# Iteration 7, inertia 119780.65156777289.
# Iteration 8, inertia 119640.33973110626.
# Iteration 9, inertia 119499.60792925517.
# Iteration 10, inertia 119396.5320727382.
# Iteration 11, inertia 119311.34999704348.
# Iteration 12, inertia 119263.42218797264.
# Iteration 13, inertia 119233.06517478915.
# Iteration 14, inertia 119199.33767325213.
# Iteration 15, inertia 119162.32480212508.
# Converged at iteration 15: strict convergence.
# Initialization complete
# Iteration 0, inertia 175370.0169266981.
# Iteration 1, inertia 126473.74338648934.
# Iteration 2, inertia 123652.96837189482.
# Iteration 3, inertia 122775.60620023556.
# Iteration 4, inertia 122278.91240827121.
# Iteration 5, inertia 121983.31691180449.
# Iteration 6, inertia 121295.19988065572.
# Iteration 7, inertia 120721.12251699068.
# Iteration 8, inertia 120619.37952988254.
# Iteration 9, inertia 120569.54730990143.
# Converged at iteration 9: strict convergence.
# Initialization complete
# Iteration 0, inertia 167090.48075464478.
# Iteration 1, inertia 125405.36011756402.
# Iteration 2, inertia 122879.60191425211.
# Iteration 3, inertia 121964.75813602011.
# Iteration 4, inertia 121515.14908181448.
# Iteration 5, inertia 121174.58285561827.
# Iteration 6, inertia 120993.79264626949.
# Iteration 7, inertia 120801.80838787518.
# Iteration 8, inertia 120601.88982436748.
# Iteration 9, inertia 120480.20141248673.
# Iteration 10, inertia 120274.89975567436.
# Iteration 11, inertia 120202.65420108612.
# Iteration 12, inertia 120113.35115130928.
# Iteration 13, inertia 119982.448924955.
# Iteration 14, inertia 119873.58487950727.
# Iteration 15, inertia 119756.27905931034.
# Iteration 16, inertia 119599.92808513896.
# Iteration 17, inertia 119400.76883514531.
# Iteration 18, inertia 119359.792142649.
# Iteration 19, inertia 119341.00469572801.
# Iteration 20, inertia 119288.01804508525.
# Iteration 21, inertia 119273.89353184057.
# Iteration 22, inertia 119265.55085771126.
# Iteration 23, inertia 119214.15809413728.
# Iteration 24, inertia 119147.69400201464.
# Iteration 25, inertia 119101.54373524732.
# Iteration 26, inertia 119081.22973162646.
# Iteration 27, inertia 119064.13963729994.
# Converged at iteration 27: strict convergence.
# Initialization complete
# Iteration 0, inertia 173119.2530954585.
# Iteration 1, inertia 124132.88657203854.
# Iteration 2, inertia 122453.1345402178.
# Iteration 3, inertia 122085.38172304234.
# Iteration 4, inertia 121646.21723928221.
# Iteration 5, inertia 121284.35288113485.
# Iteration 6, inertia 121056.44578613239.
# Iteration 7, inertia 121008.60442751586.
# Iteration 8, inertia 120998.76482968472.
# Iteration 9, inertia 120986.73044417643.
# Converged at iteration 9: strict convergence.
# Initialization complete
# Iteration 0, inertia 171454.87824210103.
# Iteration 1, inertia 122721.42826101235.
# Iteration 2, inertia 119251.26769830067.
# Iteration 3, inertia 117400.26635881783.
# Iteration 4, inertia 116345.85906163935.
# Iteration 5, inertia 116159.39734948713.
# Iteration 6, inertia 116072.61057697331.
# Iteration 7, inertia 116063.59101169705.
# Iteration 8, inertia 116047.28287886028.
# Iteration 9, inertia 116042.84752316793.
# Converged at iteration 9: strict convergence.
# Initialization complete
# Iteration 0, inertia 178953.16872808352.
# Iteration 1, inertia 127222.67575477879.
# Iteration 2, inertia 124491.79258643137.
# Iteration 3, inertia 123196.98567321003.
# Iteration 4, inertia 122494.92287356665.
# Iteration 5, inertia 121995.9232518334.
# Iteration 6, inertia 121538.28656940351.
# Iteration 7, inertia 121134.42647352524.
# Iteration 8, inertia 120973.64664039828.
# Iteration 9, inertia 120812.76982159655.
# Iteration 10, inertia 120757.7536617758.
# Iteration 11, inertia 120555.47219691057.
# Iteration 12, inertia 120321.97787071728.
# Converged at iteration 12: strict convergence.
# Initialization complete
# Iteration 0, inertia 173033.6192927694.
# Iteration 1, inertia 126100.35961154058.
# Iteration 2, inertia 123614.9615857212.
# Iteration 3, inertia 122899.80556020413.
# Iteration 4, inertia 122564.49699288997.
# Iteration 5, inertia 122320.62959263509.
# Iteration 6, inertia 122063.19788997152.
# Iteration 7, inertia 121549.54775486595.
# Iteration 8, inertia 121222.73156918048.
# Iteration 9, inertia 120804.8055111975.
# Iteration 10, inertia 120728.67499604082.
# Iteration 11, inertia 120640.78887803818.
# Iteration 12, inertia 120402.23341214286.
# Iteration 13, inertia 120332.55971716823.
# Iteration 14, inertia 120295.37789813083.
# Iteration 15, inertia 120178.6024820027.
# Iteration 16, inertia 120089.07318757317.
# Iteration 17, inertia 119982.34730442296.
# Iteration 18, inertia 119903.92124560683.
# Iteration 19, inertia 119900.69572172.
# Converged at iteration 19: strict convergence.
# Initialization complete
# Iteration 0, inertia 174197.61307283246.
# Iteration 1, inertia 126341.89401601613.
# Iteration 2, inertia 122703.15978020987.
# Iteration 3, inertia 120514.31077942396.
# Iteration 4, inertia 119100.86354998694.
# Iteration 5, inertia 118297.30443295187.
# Iteration 6, inertia 117961.61679515352.
# Iteration 7, inertia 117415.38246515638.
# Iteration 8, inertia 117008.97402614071.
# Iteration 9, inertia 116782.2779237962.
# Iteration 10, inertia 116449.72252796323.
# Converged at iteration 10: strict convergence.
# Initialization complete
# Iteration 0, inertia 178725.14327050772.
# Iteration 1, inertia 124572.31254366122.
# Iteration 2, inertia 122094.32478543051.
# Iteration 3, inertia 121185.69369843324.
# Iteration 4, inertia 120534.50266417781.
# Iteration 5, inertia 120184.12410308614.
# Iteration 6, inertia 119839.18174608398.
# Iteration 7, inertia 119401.96840858995.
# Iteration 8, inertia 119019.24023406202.
# Iteration 9, inertia 118799.53047450076.
# Iteration 10, inertia 118600.4726600505.
# Iteration 11, inertia 118389.0213608518.
# Iteration 12, inertia 118182.87766798183.
# Iteration 13, inertia 117990.8150761457.
# Iteration 14, inertia 117950.55544377162.
# Iteration 15, inertia 117832.82816435503.
# Iteration 16, inertia 117784.29861734765.
# Converged at iteration 16: strict convergence.
# Initialization complete
# Iteration 0, inertia 175183.09701296108.
# Iteration 1, inertia 124860.92218284261.
# Iteration 2, inertia 121892.02772835824.
# Iteration 3, inertia 120549.04342677168.
# Iteration 4, inertia 119828.61389458891.
# Iteration 5, inertia 119432.24164151949.
# Iteration 6, inertia 119293.32679129831.
# Iteration 7, inertia 119213.5115515591.
# Iteration 8, inertia 119133.35853883282.
# Iteration 9, inertia 119101.8652930779.
# Iteration 10, inertia 119064.24428422237.
# Iteration 11, inertia 119045.77855165521.
# Converged at iteration 11: strict convergence.
# KMeans(n_clusters=20, random_state=25, verbose=2)

# %%
selectGroup = []
ativosGroup = []
meanGroup = []
columns = []

for i in range(quantAtivos):
    columns.append('Grupo {}'.format(i))

for group in np.unique(kmeans.labels_, return_counts=True)[0]:
    filter = kmeans.labels_ == group
    selectGroup.append(filter)
    ativosGroup.append(dfScaled.T[filter].index)
    meanGroup.append(dfScaled.T[filter].mean())
    
    
setorGroups = pd.DataFrame(np.zeros(shape = (len(setores), len(selectGroup)), dtype = int),
                           index = setores.keys(),
                           columns = columns)
    
for group in range(len(ativosGroup)):
    for ativo in ativosGroup[group]:
        for setor in setores.keys():
            if ativo in setores[setor]:
                setorGroups.loc[setor, setorGroups.columns[group]] += 1

# %%
setorGroups.T.plot.bar(stacked=True);

# %%
setorGroups.plot.bar(stacked=True);

# %%
mediaDF = pd.DataFrame(index = columns, columns = ["H", "c"])

# %%
sns.set_style("darkgrid")

time = datetime.now().strftime('%d-%B-%Ih%Mmin')
SP500IndexPct = SP500_index.pct_change().dropna()['SP500']

obs_matriz = np.expand_dims(np.vstack([[SP500IndexPct],
                                       [np.ones(len(samplePctAAL))]]).T, axis = 1)

kf = KalmanFilter(initial_state_mean = [0, 0],
                  initial_state_covariance = np.ones((2, 2)),
                  transition_matrices = np.eye(2),
                  observation_matrices = obs_matriz)

outdir = './graphics/2º Fase/{}'.format(time)
if not os.path.exists(outdir):
    os.mkdir(outdir)

for group in range(quantAtivos):
    H, c, data = compute_Hc(meanGroup[group].to_numpy() + 10, kind='price', simplified=True)
    '''
    f, ax = plt.subplots()
    ax.plot(data[0], c*data[0]**H, color="deepskyblue")
    ax.scatter(data[0], data[1], color="purple")
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel('Time interval')
    ax.set_ylabel('R/S ratio')
    ax.grid(True)
    plt.show()
    '''
    
    mediaDF.loc[mediaDF.index[group], "H"] = H
    mediaDF.loc[mediaDF.index[group], "c"] = c
    
    stateMeans, stateCovs = kf.filter(meanGroup[group].pct_change().dropna())

    fig, ax = plt.subplots()
    ax.plot(SP500IndexPct.index, stateMeans[:, 0])
    ax.set_title("GRUPO {}".format(group))
    ax.set(xlabel='Data', ylabel = 'Coeficiente Beta')
    nameGraphic = '{} Coeficiente Beta.png'.format(group)
    fullname = os.path.join(outdir, nameGraphic)
    plt.savefig(fullname)
    plt.close(fig)
    
    stl = STL(meanGroup[group], period=365).fit()
    
    fig = stl.plot()
    ax.set_title("GRUPO {}".format(group))
    nameGraphic = '{} STL.png'.format(group)
    fullname = os.path.join(outdir, nameGraphic)
    plt.savefig(fullname)
    plt.close(fig)
       
    fig, ax = plt.subplots()
    dfScaled.T[selectGroup[group]].T.plot(ax = ax)
    ax.set_title("GRUPO {}".format(group))
    ax.set(xlabel='Data', ylabel='Preço Normalizado($)')
    nameGraphic = '{} Grupo.png'.format(group)
    fullname = os.path.join(outdir, nameGraphic)
    plt.savefig(fullname)
    plt.close(fig)
    
    fig, ax = plt.subplots()
    meanGroup[group].plot(ax = ax)
    ax.set_title("MEDIA GRUPAL {}".format(group))
    ax.set(xlabel='Data', ylabel='Preço Normalizado($)')
    nameGraphic = '{} Media Grupal.png'.format(group)
    fullname = os.path.join(outdir, nameGraphic)
    plt.savefig(fullname)
    plt.close(fig)
#------------------------------------------------------------------------------------------------------------

# %%
mediaDF
# Out:
#                  H         c
# Grupo 0   0.638765  0.949393
# Grupo 1   0.607381  0.975246
# Grupo 2   0.574574  1.100734
# Grupo 3   0.617583  0.972629
# Grupo 4   0.631539  0.960934
# Grupo 5   0.615436  0.982778
# Grupo 6   0.494121  1.388099
# Grupo 7   0.565317  1.183597
# Grupo 8   0.622732  0.955818
# Grupo 9   0.604437  0.999769
# Grupo 10  0.604676  1.002071
# Grupo 11  0.565373  1.082455
# Grupo 12  0.568716  1.069856
# Grupo 13  0.556727  1.181616
# Grupo 14  0.626742  0.943676
# Grupo 15  0.503803  1.316195
# Grupo 16  0.559734  1.127274
# Grupo 17  0.615319  1.012446
# Grupo 18  0.509713  1.329789
# Grupo 19   0.65354  0.855411
