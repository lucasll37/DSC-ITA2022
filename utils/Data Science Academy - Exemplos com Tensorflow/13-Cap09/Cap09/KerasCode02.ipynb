# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Deep Learning Frameworks</font>

# %% [markdown]
# # Keras - Multilayer Perceptron

# %% [markdown]
# Historicamente, Perceptron foi o nome dado a um modelo de rede neural com uma única camada linear. Se o modelo tem múltiplas camadas, chamamos de Perceptron Multicamada (MLP). Cada nó na primeira camada recebe uma entrada e dispara de acordo com os limites de decisão locais predefinidos (threesholds). Em seguida, a saída da primeira camada é passada para a segunda camada, cujos resultados são passados para a camada de saída final consistindo de um único neurônio.
#
# A rede pode ser densa, o que significa que cada neurônio em uma camada está conectado a todos os neurônios localizados na camada anterior e a todos os neurônios na camada seguinte.

# %% [markdown]
# ### Treinando Redes Neurais com Keras

# %% [markdown]
# Vamos considerar um único neurônio. Quais são as melhores escolhas para o peso w e o bias b? Idealmente, gostaríamos de fornecer um conjunto de exemplos de treinamento e deixar o computador ajustar o peso e o bias de tal forma que os erros produzidos na saída sejam minimizados. A fim de tornar isso um pouco mais concreto, vamos supor que temos um conjunto de imagens de gatos e outro conjunto separado de imagens que não contenham gatos. Por uma questão de simplicidade, suponha que cada neurônio olhe para um único valor de pixel de entrada. Enquanto o computador processa essas imagens, gostaríamos que nosso neurônio ajustasse seus pesos e bias para que tenhamos menos e menos imagens erroneamente reconhecidas como não-gatos. Essa abordagem parece muito intuitiva, mas exige que uma pequena alteração nos pesos (e/ou bias) cause apenas uma pequena mudança nas saídas.

# %% [markdown]
# Se tivermos um grande salto de saída, não podemos aprender progressivamente. Afinal, as crianças aprendem pouco a pouco. Infelizmente, o perceptron não mostra esse comportamento "pouco a pouco". Um perceptron é 0 ou 1 e isso é um grande salto e não vai ajudá-lo a aprender. Precisamos de algo diferente, mais suave. Precisamos de uma função que mude progressivamente de 0 para 1 sem descontinuidade. Matematicamente, isso significa que precisamos de uma função contínua que nos permita calcular a derivada.

# %% [markdown]
# Cada neurônio pode ser inicializado com pesos específicos. Keras oferece algumas opções, a mais comum das quais são listadas da seguinte forma:
#
# Random_uniform: Os pesos são inicializados com valores uniformemente pequenos e aleatórios em (-0,05, 0,05).
#
# Random_normal: Os pesos são inicializados de acordo com uma distribuição Gaussiana, com média zero e pequeno desvio padrão de 0,05.
#
# Zero: Todos os pesos são inicializados para zero.

# %% [markdown]
# Inicializadores em Keras: https://keras.io/initializers/

# %% [markdown]
# ### Funções de Ativação

# %% [markdown]
# https://keras.io/activations/

# %% [markdown]
# ### Função Sigmóide

# %% [markdown]
# A função sigmóide é uma função matemática de amplo uso em campos como a economia e a computação. O nome "sigmóide" vem da forma em S do seu gráfico.

# %% [markdown]
# Um neurônio pode usar o sigmóide para calcular a função não-linear. Um neurônio com ativação sigmóide tem um comportamento semelhante ao perceptron, mas as mudanças são graduais e os valores de saída, como 0.3537 ou 0.147191, são perfeitamente legítimos.

# %% [markdown]
# A função de ativação sigmóide é comumente utilizada por redes neurais com propagação positiva (Feedforward) que precisam ter como saída apenas números positivos, em redes neurais multicamadas e em outras redes com sinais contínuos.

# %% [markdown]
# ### Função ReLu

# %% [markdown]
# O sigmóide não é o único tipo de função de ativação suave usada para redes neurais. Recentemente, uma função muito simples chamada unidade linear rectificada (ReLU) tornou-se muito popular porque gera resultados experimentais muito bons. Uma ReLU é simplesmente definida como uma função não-linear e a função é zero para valores negativos e cresce linearmente para valores positivos.

# %% [markdown]
# Sigmoid e ReLU são geralmente chamados funções de ativação das redes neurais. Essas mudanças graduais, típicas das funções Sigmóide e ReLU, são os blocos básicos para o desenvolvimento de um algoritmo de aprendizado que se adapta pouco a pouco, reduzindo progressivamente os erros cometidos pelas redes.

# %% [markdown]
# ### Reconhecimento de Dígitos

# %% [markdown]
# Vamos construir uma rede que pode reconhecer números manuscritos. Para alcançar esse objetivo, usamos o MNIST (http://yann.lecun.com/exdb/mnist), um banco de dados de dígitos manuscritos composto por um conjunto de treinamento de 60.000 exemplos e um conjunto de testes de 10.000 exemplares. Os exemplos de treinamento são anotados por humanos com a resposta correta. Por exemplo, se o dígito manuscrito for o número três, então três é simplesmente o rótulo associado a esse exemplo. Cada imagem MNIST está na escala de cinza (gray scale), e consiste em 28 x 28 pixels.

# %% [markdown]
# ### One-Hot Encoding

# %% [markdown]
# Em muitas aplicações, é conveniente transformar features categóricas (não-numéricas) em variáveis numéricas. Por exemplo, o dígito de feature categórica com o valor d em [0-9] pode ser codificado em um vetor binário com 10 posições, que sempre tem valor 0, exceto a d-ésima posição onde um 1 está presente. Este tipo de representação é chamado de One-Hot Encoding (OHE) e é muito comum na mineração de dados quando o algoritmo de aprendizagem é especializado para lidar com funções numéricas.

# %% [markdown]
# # Multilayer Perceptron - Versão 1

# %% [markdown]
# Rede neural com apenas uma camada oculta

# %%
import keras
print (keras.__version__)
# Out:
# Using TensorFlow backend.
# 2.3.1

# %%
import tensorflow
print (tensorflow.__version__)
# Out:
# 2.1.0

# %%
# Import dos Pacotes
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils

# Garantindo que o resultado pode ser reproduzido
np.random.seed(1671)  

# Parâmetros da rede e do treinamento
NB_EPOCH = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # número de outputs = número de dígitos
OPTIMIZER = SGD() # otimizador SGD
N_HIDDEN = 128  # número de neurônios ocultos
VALIDATION_SPLIT = 0.2 # quanto é reservado para validação

# Gerando datasets de treino e e teste
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# X_train possui 60000 linhas de valores 28x28 --> reshape para 60000 x 784
# Gera versão final dos datasetes de treino e de teste
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalizando os dados
# Tipicamente, os valores associados a cada pixel são normalizados na faixa [0, 1] 
# (o que significa que a intensidade de cada pixel é dividida por 255, o valor de intensidade máxima). 
# A saída é 10 classes, uma para cada dígito.
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'exemplos de treino')
print(X_test.shape[0], 'exemplos de teste')

# Converte os vetores da class para matrizes binárias das classes
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# Cria as camadas
# A camada final usa a função de ativação softmax, que é uma generalização da função sigmóide. 
# Softmax transforma um vetor k-dimensional de valores reais arbitrários em um vetor k-dimensional de valores reais no 
# intervalo (0, 1). No nosso caso, agrega 10 respostas fornecidas pela camada anterior com 10 neurônios.
model = Sequential()
model.add(Dense(NB_CLASSES, input_shape = (RESHAPED,)))
model.add(Activation('softmax'))

# Sumário
model.summary()

# Compila o modelo
# Precisamos selecionar o otimizador que é o algoritmo específico usado para atualizar pesos enquanto 
# treinamos nosso modelo.
# Precisamos selecionar também a função objetivo que é usada pelo otimizador para navegar no espaço de pesos 
# (frequentemente, as funções objetivo são chamadas de função de perda (loss) e o processo de otimização é definido 
# como um processo de minimização de perdas).
# Outras funções aqui: https://keras.io/losses/
# A função objetivo "categorical_crossentropy" é a função objetivo adequada para predições de rótulos multiclass. 
# É também a escolha padrão em associação com a ativação softmax.
# A métrica é usada para medir a performance do modelo. Outras métricas: https://keras.io/metrics/
# As métricas são semelhantes às funções objetivo, com a única diferença de que elas não são usadas para 
# treinar um modelo, mas apenas para avaliar um modelo. 
model.compile(loss = 'categorical_crossentropy', optimizer = OPTIMIZER, metrics = ['accuracy'])

# Treina o modelo
# Epochs: Este é o número de vezes que o modelo é exposto ao conjunto de treinamento. Em cada iteração, 
# o otimizador tenta ajustar os pesos para que a função objetivo seja minimizada. 
# Batch_size: Esse é o número de instâncias de treinamento observadas antes que o otimizador execute uma 
# atualização de peso.
# Reservamos parte do conjunto de treinamento para validação. A idéia chave é que reservamos uma parte dos 
# dados de treinamento para medir o desempenho na validação durante o treinamento. 
# Esta é uma boa prática para qualquer tarefa de aprendizagem da máquina, que vamos adotar em todos os nossos exemplos.
modelo_v1 = model.fit(X_train, Y_train,
                      batch_size = BATCH_SIZE, 
                      epochs = NB_EPOCH,
                      verbose = VERBOSE, 
                      validation_split = VALIDATION_SPLIT)

# Avalia o modelo com os dados de teste
# Uma vez treinado o modelo, podemos avaliá-lo no conjunto de testes que contém novos exemplos não vistos. 
# Desta forma, podemos obter o valor mínimo alcançado pela função objetivo e o melhor valor alcançado pela métrica 
# de avaliação. Note-se que o conjunto de treinamento e o conjunto de teste são rigorosamente separados. 
# Não vale a pena avaliar um modelo em um exemplo que já foi usado para treinamento. 
# A aprendizagem é essencialmente um processo destinado a generalizar observações invisíveis e não a memorizar 
# o que já é conhecido.
score = model.evaluate(X_test, Y_test, verbose = VERBOSE)

# Imprime a perda e a acurácia
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 exemplos de treino
# 10000 exemplos de teste
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                7850
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
# 48000/48000 [==============================] - 0s 8us/step - loss: 1.3633 - accuracy: 0.6796 - val_loss: 0.8904 - val_accuracy: 0.8246
# Epoch 2/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.7913 - accuracy: 0.8272 - val_loss: 0.6572 - val_accuracy: 0.8546
# Epoch 3/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.6436 - accuracy: 0.8497 - val_loss: 0.5625 - val_accuracy: 0.8681
# Epoch 4/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.5717 - accuracy: 0.8602 - val_loss: 0.5098 - val_accuracy: 0.8765
# Epoch 5/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.5276 - accuracy: 0.8677 - val_loss: 0.4758 - val_accuracy: 0.8826
# Epoch 6/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4973 - accuracy: 0.8726 - val_loss: 0.4515 - val_accuracy: 0.8866
# Epoch 7/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4748 - accuracy: 0.8775 - val_loss: 0.4333 - val_accuracy: 0.8882
# Epoch 8/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4574 - accuracy: 0.8803 - val_loss: 0.4189 - val_accuracy: 0.8920
# Epoch 9/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4433 - accuracy: 0.8834 - val_loss: 0.4075 - val_accuracy: 0.8939
# Epoch 10/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4317 - accuracy: 0.8850 - val_loss: 0.3977 - val_accuracy: 0.8966
# Epoch 11/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4218 - accuracy: 0.8873 - val_loss: 0.3896 - val_accuracy: 0.8984
# Epoch 12/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4134 - accuracy: 0.8888 - val_loss: 0.3827 - val_accuracy: 0.8995
# Epoch 13/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.4060 - accuracy: 0.8903 - val_loss: 0.3766 - val_accuracy: 0.9003
# Epoch 14/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3995 - accuracy: 0.8918 - val_loss: 0.3712 - val_accuracy: 0.9013
# Epoch 15/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3936 - accuracy: 0.8928 - val_loss: 0.3664 - val_accuracy: 0.9016
# Epoch 16/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3884 - accuracy: 0.8945 - val_loss: 0.3621 - val_accuracy: 0.9031
# Epoch 17/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3837 - accuracy: 0.8950 - val_loss: 0.3582 - val_accuracy: 0.9032
# Epoch 18/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3794 - accuracy: 0.8962 - val_loss: 0.3546 - val_accuracy: 0.9039
# Epoch 19/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3755 - accuracy: 0.8970 - val_loss: 0.3514 - val_accuracy: 0.9048
# Epoch 20/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3718 - accuracy: 0.8979 - val_loss: 0.3485 - val_accuracy: 0.9053
# Epoch 21/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3685 - accuracy: 0.8985 - val_loss: 0.3457 - val_accuracy: 0.9058
# Epoch 22/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3653 - accuracy: 0.8995 - val_loss: 0.3431 - val_accuracy: 0.9057
# Epoch 23/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3625 - accuracy: 0.8999 - val_loss: 0.3407 - val_accuracy: 0.9063
# Epoch 24/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3598 - accuracy: 0.9008 - val_loss: 0.3385 - val_accuracy: 0.9070
# Epoch 25/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3572 - accuracy: 0.9012 - val_loss: 0.3364 - val_accuracy: 0.9074
# Epoch 26/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3548 - accuracy: 0.9019 - val_loss: 0.3345 - val_accuracy: 0.9084
# Epoch 27/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3525 - accuracy: 0.9022 - val_loss: 0.3326 - val_accuracy: 0.9082
# Epoch 28/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3504 - accuracy: 0.9032 - val_loss: 0.3311 - val_accuracy: 0.9090
# Epoch 29/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3484 - accuracy: 0.9031 - val_loss: 0.3293 - val_accuracy: 0.9094
# Epoch 30/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3465 - accuracy: 0.9041 - val_loss: 0.3277 - val_accuracy: 0.9097
# Epoch 31/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3447 - accuracy: 0.9044 - val_loss: 0.3264 - val_accuracy: 0.9097
# Epoch 32/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3430 - accuracy: 0.9047 - val_loss: 0.3249 - val_accuracy: 0.9097
# Epoch 33/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3413 - accuracy: 0.9051 - val_loss: 0.3235 - val_accuracy: 0.9103
# Epoch 34/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3397 - accuracy: 0.9056 - val_loss: 0.3222 - val_accuracy: 0.9104
# Epoch 35/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3382 - accuracy: 0.9058 - val_loss: 0.3211 - val_accuracy: 0.9110
# Epoch 36/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3368 - accuracy: 0.9062 - val_loss: 0.3198 - val_accuracy: 0.9110
# Epoch 37/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3353 - accuracy: 0.9069 - val_loss: 0.3187 - val_accuracy: 0.9117
# Epoch 38/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3340 - accuracy: 0.9075 - val_loss: 0.3177 - val_accuracy: 0.9120
# Epoch 39/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3327 - accuracy: 0.9075 - val_loss: 0.3166 - val_accuracy: 0.9122
# Epoch 40/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3314 - accuracy: 0.9078 - val_loss: 0.3159 - val_accuracy: 0.9118
# Epoch 41/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3303 - accuracy: 0.9080 - val_loss: 0.3147 - val_accuracy: 0.9128
# Epoch 42/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3291 - accuracy: 0.9084 - val_loss: 0.3138 - val_accuracy: 0.9132
# Epoch 43/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3280 - accuracy: 0.9089 - val_loss: 0.3130 - val_accuracy: 0.9132
# Epoch 44/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3270 - accuracy: 0.9091 - val_loss: 0.3121 - val_accuracy: 0.9132
# Epoch 45/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3259 - accuracy: 0.9093 - val_loss: 0.3113 - val_accuracy: 0.9135
# Epoch 46/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3249 - accuracy: 0.9095 - val_loss: 0.3105 - val_accuracy: 0.9137
# Epoch 47/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3239 - accuracy: 0.9105 - val_loss: 0.3098 - val_accuracy: 0.9141
# Epoch 48/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3230 - accuracy: 0.9105 - val_loss: 0.3090 - val_accuracy: 0.9146
# Epoch 49/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3221 - accuracy: 0.9102 - val_loss: 0.3083 - val_accuracy: 0.9151
# Epoch 50/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3212 - accuracy: 0.9109 - val_loss: 0.3075 - val_accuracy: 0.9150
# Epoch 51/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3204 - accuracy: 0.9108 - val_loss: 0.3070 - val_accuracy: 0.9151
# Epoch 52/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3195 - accuracy: 0.9112 - val_loss: 0.3063 - val_accuracy: 0.9148
# Epoch 53/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3187 - accuracy: 0.9114 - val_loss: 0.3057 - val_accuracy: 0.9153
# Epoch 54/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3180 - accuracy: 0.9117 - val_loss: 0.3050 - val_accuracy: 0.9149
# Epoch 55/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3172 - accuracy: 0.9121 - val_loss: 0.3044 - val_accuracy: 0.9149
# Epoch 56/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3164 - accuracy: 0.9120 - val_loss: 0.3037 - val_accuracy: 0.9156
# Epoch 57/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3157 - accuracy: 0.9128 - val_loss: 0.3034 - val_accuracy: 0.9152
# Epoch 58/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3149 - accuracy: 0.9121 - val_loss: 0.3029 - val_accuracy: 0.9148
# Epoch 59/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3143 - accuracy: 0.9128 - val_loss: 0.3022 - val_accuracy: 0.9151
# Epoch 60/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3136 - accuracy: 0.9129 - val_loss: 0.3016 - val_accuracy: 0.9161
# Epoch 61/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3130 - accuracy: 0.9132 - val_loss: 0.3011 - val_accuracy: 0.9158
# Epoch 62/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3123 - accuracy: 0.9131 - val_loss: 0.3007 - val_accuracy: 0.9152
# Epoch 63/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3117 - accuracy: 0.9135 - val_loss: 0.3003 - val_accuracy: 0.9157
# Epoch 64/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3111 - accuracy: 0.9136 - val_loss: 0.2997 - val_accuracy: 0.9158
# Epoch 65/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3105 - accuracy: 0.9137 - val_loss: 0.2992 - val_accuracy: 0.9159
# Epoch 66/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3099 - accuracy: 0.9138 - val_loss: 0.2988 - val_accuracy: 0.9159
# Epoch 67/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3093 - accuracy: 0.9142 - val_loss: 0.2984 - val_accuracy: 0.9164
# Epoch 68/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3088 - accuracy: 0.9139 - val_loss: 0.2979 - val_accuracy: 0.9166
# Epoch 69/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3082 - accuracy: 0.9143 - val_loss: 0.2976 - val_accuracy: 0.9165
# Epoch 70/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3077 - accuracy: 0.9145 - val_loss: 0.2971 - val_accuracy: 0.9167
# Epoch 71/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3071 - accuracy: 0.9146 - val_loss: 0.2967 - val_accuracy: 0.9172
# Epoch 72/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3067 - accuracy: 0.9146 - val_loss: 0.2964 - val_accuracy: 0.9167
# Epoch 73/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3061 - accuracy: 0.9150 - val_loss: 0.2961 - val_accuracy: 0.9170
# Epoch 74/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3056 - accuracy: 0.9150 - val_loss: 0.2956 - val_accuracy: 0.9171
# Epoch 75/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3051 - accuracy: 0.9151 - val_loss: 0.2953 - val_accuracy: 0.9178
# Epoch 76/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3047 - accuracy: 0.9152 - val_loss: 0.2950 - val_accuracy: 0.9173
# Epoch 77/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3042 - accuracy: 0.9154 - val_loss: 0.2946 - val_accuracy: 0.9171
# Epoch 78/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3037 - accuracy: 0.9154 - val_loss: 0.2943 - val_accuracy: 0.9177
# Epoch 79/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3033 - accuracy: 0.9157 - val_loss: 0.2939 - val_accuracy: 0.9178
# Epoch 80/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3029 - accuracy: 0.9156 - val_loss: 0.2936 - val_accuracy: 0.9179
# Epoch 81/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3024 - accuracy: 0.9157 - val_loss: 0.2933 - val_accuracy: 0.9180
# Epoch 82/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3020 - accuracy: 0.9158 - val_loss: 0.2930 - val_accuracy: 0.9181
# Epoch 83/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3015 - accuracy: 0.9160 - val_loss: 0.2927 - val_accuracy: 0.9182
# Epoch 84/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3011 - accuracy: 0.9160 - val_loss: 0.2924 - val_accuracy: 0.9183
# Epoch 85/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3007 - accuracy: 0.9165 - val_loss: 0.2920 - val_accuracy: 0.9184
# Epoch 86/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3003 - accuracy: 0.9164 - val_loss: 0.2918 - val_accuracy: 0.9186
# Epoch 87/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.3000 - accuracy: 0.9165 - val_loss: 0.2915 - val_accuracy: 0.9187
# Epoch 88/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2996 - accuracy: 0.9168 - val_loss: 0.2911 - val_accuracy: 0.9190
# Epoch 89/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2992 - accuracy: 0.9168 - val_loss: 0.2909 - val_accuracy: 0.9191
# Epoch 90/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2988 - accuracy: 0.9170 - val_loss: 0.2907 - val_accuracy: 0.9191
# Epoch 91/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2985 - accuracy: 0.9167 - val_loss: 0.2903 - val_accuracy: 0.9193
# Epoch 92/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2981 - accuracy: 0.9170 - val_loss: 0.2901 - val_accuracy: 0.9196
# Epoch 93/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2977 - accuracy: 0.9171 - val_loss: 0.2898 - val_accuracy: 0.9196
# Epoch 94/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2974 - accuracy: 0.9172 - val_loss: 0.2896 - val_accuracy: 0.9196
# Epoch 95/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2970 - accuracy: 0.9174 - val_loss: 0.2894 - val_accuracy: 0.9196
# Epoch 96/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2967 - accuracy: 0.9174 - val_loss: 0.2891 - val_accuracy: 0.9198
# Epoch 97/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2964 - accuracy: 0.9177 - val_loss: 0.2889 - val_accuracy: 0.9197
# Epoch 98/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2960 - accuracy: 0.9174 - val_loss: 0.2886 - val_accuracy: 0.9201
# Epoch 99/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2957 - accuracy: 0.9176 - val_loss: 0.2884 - val_accuracy: 0.9200
# Epoch 100/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2954 - accuracy: 0.9178 - val_loss: 0.2882 - val_accuracy: 0.9202
# Epoch 101/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2951 - accuracy: 0.9179 - val_loss: 0.2879 - val_accuracy: 0.9202
# Epoch 102/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2948 - accuracy: 0.9179 - val_loss: 0.2877 - val_accuracy: 0.9202
# Epoch 103/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2945 - accuracy: 0.9180 - val_loss: 0.2876 - val_accuracy: 0.9202
# Epoch 104/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2941 - accuracy: 0.9183 - val_loss: 0.2874 - val_accuracy: 0.9202
# Epoch 105/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2939 - accuracy: 0.9183 - val_loss: 0.2871 - val_accuracy: 0.9205
# Epoch 106/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2936 - accuracy: 0.9183 - val_loss: 0.2869 - val_accuracy: 0.9202
# Epoch 107/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2932 - accuracy: 0.9186 - val_loss: 0.2867 - val_accuracy: 0.9206
# Epoch 108/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2930 - accuracy: 0.9185 - val_loss: 0.2864 - val_accuracy: 0.9209
# Epoch 109/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2927 - accuracy: 0.9185 - val_loss: 0.2863 - val_accuracy: 0.9204
# Epoch 110/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2924 - accuracy: 0.9187 - val_loss: 0.2861 - val_accuracy: 0.9204
# Epoch 111/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2922 - accuracy: 0.9183 - val_loss: 0.2858 - val_accuracy: 0.9209
# Epoch 112/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2919 - accuracy: 0.9187 - val_loss: 0.2857 - val_accuracy: 0.9207
# Epoch 113/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2916 - accuracy: 0.9189 - val_loss: 0.2855 - val_accuracy: 0.9210
# Epoch 114/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2913 - accuracy: 0.9188 - val_loss: 0.2853 - val_accuracy: 0.9212
# Epoch 115/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2911 - accuracy: 0.9189 - val_loss: 0.2853 - val_accuracy: 0.9206
# Epoch 116/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2908 - accuracy: 0.9190 - val_loss: 0.2849 - val_accuracy: 0.9213
# Epoch 117/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2906 - accuracy: 0.9193 - val_loss: 0.2848 - val_accuracy: 0.9214
# Epoch 118/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2903 - accuracy: 0.9193 - val_loss: 0.2846 - val_accuracy: 0.9213
# Epoch 119/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2901 - accuracy: 0.9193 - val_loss: 0.2845 - val_accuracy: 0.9211
# Epoch 120/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2898 - accuracy: 0.9192 - val_loss: 0.2843 - val_accuracy: 0.9213
# Epoch 121/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2896 - accuracy: 0.9191 - val_loss: 0.2841 - val_accuracy: 0.9212
# Epoch 122/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2893 - accuracy: 0.9192 - val_loss: 0.2840 - val_accuracy: 0.9212
# Epoch 123/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2891 - accuracy: 0.9194 - val_loss: 0.2839 - val_accuracy: 0.9211
# Epoch 124/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2888 - accuracy: 0.9197 - val_loss: 0.2837 - val_accuracy: 0.9210
# Epoch 125/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2886 - accuracy: 0.9193 - val_loss: 0.2835 - val_accuracy: 0.9207
# Epoch 126/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2884 - accuracy: 0.9196 - val_loss: 0.2834 - val_accuracy: 0.9218
# Epoch 127/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2882 - accuracy: 0.9194 - val_loss: 0.2833 - val_accuracy: 0.9211
# Epoch 128/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2879 - accuracy: 0.9194 - val_loss: 0.2830 - val_accuracy: 0.9211
# Epoch 129/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2877 - accuracy: 0.9196 - val_loss: 0.2828 - val_accuracy: 0.9216
# Epoch 130/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2875 - accuracy: 0.9197 - val_loss: 0.2827 - val_accuracy: 0.9215
# Epoch 131/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2872 - accuracy: 0.9199 - val_loss: 0.2827 - val_accuracy: 0.9211
# Epoch 132/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2870 - accuracy: 0.9196 - val_loss: 0.2824 - val_accuracy: 0.9213
# Epoch 133/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2868 - accuracy: 0.9197 - val_loss: 0.2823 - val_accuracy: 0.9216
# Epoch 134/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2866 - accuracy: 0.9198 - val_loss: 0.2822 - val_accuracy: 0.9213
# Epoch 135/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2864 - accuracy: 0.9202 - val_loss: 0.2821 - val_accuracy: 0.9215
# Epoch 136/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2862 - accuracy: 0.9197 - val_loss: 0.2819 - val_accuracy: 0.9213
# Epoch 137/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2860 - accuracy: 0.9198 - val_loss: 0.2818 - val_accuracy: 0.9215
# Epoch 138/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2858 - accuracy: 0.9202 - val_loss: 0.2816 - val_accuracy: 0.9218
# Epoch 139/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2856 - accuracy: 0.9202 - val_loss: 0.2815 - val_accuracy: 0.9217
# Epoch 140/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2854 - accuracy: 0.9201 - val_loss: 0.2813 - val_accuracy: 0.9215
# Epoch 141/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2852 - accuracy: 0.9203 - val_loss: 0.2812 - val_accuracy: 0.9216
# Epoch 142/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2850 - accuracy: 0.9201 - val_loss: 0.2811 - val_accuracy: 0.9218
# Epoch 143/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2848 - accuracy: 0.9205 - val_loss: 0.2810 - val_accuracy: 0.9219
# Epoch 144/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2846 - accuracy: 0.9207 - val_loss: 0.2809 - val_accuracy: 0.9217
# Epoch 145/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2845 - accuracy: 0.9208 - val_loss: 0.2807 - val_accuracy: 0.9219
# Epoch 146/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2842 - accuracy: 0.9206 - val_loss: 0.2806 - val_accuracy: 0.9220
# Epoch 147/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2841 - accuracy: 0.9206 - val_loss: 0.2804 - val_accuracy: 0.9218
# Epoch 148/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2839 - accuracy: 0.9209 - val_loss: 0.2804 - val_accuracy: 0.9219
# Epoch 149/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2837 - accuracy: 0.9209 - val_loss: 0.2802 - val_accuracy: 0.9218
# Epoch 150/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2835 - accuracy: 0.9208 - val_loss: 0.2801 - val_accuracy: 0.9222
# Epoch 151/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2834 - accuracy: 0.9210 - val_loss: 0.2800 - val_accuracy: 0.9225
# Epoch 152/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2832 - accuracy: 0.9211 - val_loss: 0.2799 - val_accuracy: 0.9222
# Epoch 153/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2830 - accuracy: 0.9207 - val_loss: 0.2797 - val_accuracy: 0.9223
# Epoch 154/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2828 - accuracy: 0.9209 - val_loss: 0.2796 - val_accuracy: 0.9221
# Epoch 155/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2826 - accuracy: 0.9208 - val_loss: 0.2795 - val_accuracy: 0.9223
# Epoch 156/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2825 - accuracy: 0.9211 - val_loss: 0.2794 - val_accuracy: 0.9223
# Epoch 157/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2823 - accuracy: 0.9211 - val_loss: 0.2793 - val_accuracy: 0.9225
# Epoch 158/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2821 - accuracy: 0.9212 - val_loss: 0.2792 - val_accuracy: 0.9224
# Epoch 159/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2820 - accuracy: 0.9213 - val_loss: 0.2791 - val_accuracy: 0.9223
# Epoch 160/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2818 - accuracy: 0.9212 - val_loss: 0.2790 - val_accuracy: 0.9224
# Epoch 161/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2816 - accuracy: 0.9213 - val_loss: 0.2789 - val_accuracy: 0.9222
# Epoch 162/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2815 - accuracy: 0.9216 - val_loss: 0.2789 - val_accuracy: 0.9227
# Epoch 163/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2813 - accuracy: 0.9212 - val_loss: 0.2788 - val_accuracy: 0.9224
# Epoch 164/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2812 - accuracy: 0.9216 - val_loss: 0.2786 - val_accuracy: 0.9225
# Epoch 165/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2810 - accuracy: 0.9215 - val_loss: 0.2785 - val_accuracy: 0.9229
# Epoch 166/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2808 - accuracy: 0.9215 - val_loss: 0.2785 - val_accuracy: 0.9225
# Epoch 167/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2807 - accuracy: 0.9217 - val_loss: 0.2784 - val_accuracy: 0.9227
# Epoch 168/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2805 - accuracy: 0.9219 - val_loss: 0.2783 - val_accuracy: 0.9227
# Epoch 169/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2804 - accuracy: 0.9217 - val_loss: 0.2782 - val_accuracy: 0.9227
# Epoch 170/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2802 - accuracy: 0.9217 - val_loss: 0.2781 - val_accuracy: 0.9226
# Epoch 171/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2801 - accuracy: 0.9219 - val_loss: 0.2780 - val_accuracy: 0.9226
# Epoch 172/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2799 - accuracy: 0.9218 - val_loss: 0.2779 - val_accuracy: 0.9230
# Epoch 173/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2798 - accuracy: 0.9216 - val_loss: 0.2778 - val_accuracy: 0.9230
# Epoch 174/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2796 - accuracy: 0.9217 - val_loss: 0.2777 - val_accuracy: 0.9226
# Epoch 175/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2795 - accuracy: 0.9218 - val_loss: 0.2776 - val_accuracy: 0.9229
# Epoch 176/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2793 - accuracy: 0.9220 - val_loss: 0.2775 - val_accuracy: 0.9231
# Epoch 177/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2792 - accuracy: 0.9219 - val_loss: 0.2774 - val_accuracy: 0.9236
# Epoch 178/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2790 - accuracy: 0.9221 - val_loss: 0.2775 - val_accuracy: 0.9227
# Epoch 179/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2789 - accuracy: 0.9223 - val_loss: 0.2773 - val_accuracy: 0.9235
# Epoch 180/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2788 - accuracy: 0.9222 - val_loss: 0.2772 - val_accuracy: 0.9236
# Epoch 181/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2786 - accuracy: 0.9224 - val_loss: 0.2771 - val_accuracy: 0.9232
# Epoch 182/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2785 - accuracy: 0.9221 - val_loss: 0.2770 - val_accuracy: 0.9231
# Epoch 183/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2784 - accuracy: 0.9223 - val_loss: 0.2770 - val_accuracy: 0.9229
# Epoch 184/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2782 - accuracy: 0.9224 - val_loss: 0.2768 - val_accuracy: 0.9233
# Epoch 185/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2781 - accuracy: 0.9224 - val_loss: 0.2768 - val_accuracy: 0.9232
# Epoch 186/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2779 - accuracy: 0.9224 - val_loss: 0.2766 - val_accuracy: 0.9237
# Epoch 187/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2778 - accuracy: 0.9225 - val_loss: 0.2766 - val_accuracy: 0.9233
# Epoch 188/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2777 - accuracy: 0.9226 - val_loss: 0.2765 - val_accuracy: 0.9234
# Epoch 189/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2775 - accuracy: 0.9226 - val_loss: 0.2765 - val_accuracy: 0.9233
# Epoch 190/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2774 - accuracy: 0.9225 - val_loss: 0.2764 - val_accuracy: 0.9233
# Epoch 191/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2773 - accuracy: 0.9225 - val_loss: 0.2763 - val_accuracy: 0.9237
# Epoch 192/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2771 - accuracy: 0.9226 - val_loss: 0.2762 - val_accuracy: 0.9237
# Epoch 193/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2771 - accuracy: 0.9227 - val_loss: 0.2761 - val_accuracy: 0.9235
# Epoch 194/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2769 - accuracy: 0.9225 - val_loss: 0.2761 - val_accuracy: 0.9234
# Epoch 195/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2768 - accuracy: 0.9231 - val_loss: 0.2760 - val_accuracy: 0.9238
# Epoch 196/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2766 - accuracy: 0.9228 - val_loss: 0.2759 - val_accuracy: 0.9239
# Epoch 197/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2765 - accuracy: 0.9228 - val_loss: 0.2759 - val_accuracy: 0.9241
# Epoch 198/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2764 - accuracy: 0.9231 - val_loss: 0.2758 - val_accuracy: 0.9235
# Epoch 199/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2763 - accuracy: 0.9229 - val_loss: 0.2758 - val_accuracy: 0.9240
# Epoch 200/200
# 48000/48000 [==============================] - 0s 7us/step - loss: 0.2761 - accuracy: 0.9231 - val_loss: 0.2757 - val_accuracy: 0.9241
# 10000/10000 [==============================] - 0s 7us/step
#
# Test score: 0.27738100301027296
# Test accuracy: 0.9225000143051147

# %% [markdown]
# # Multilayer Perceptron - Versão 2

# %% [markdown]
# Adiciona 2 camadas ocultas, usando função de ativação ReLu

# %%
# Import dos Pacotes
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils

# Garantindo que o resultado pode ser reproduzido
np.random.seed(1671)  

# Parâmetros da rede e do treinamento
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # número de outputs = número de dígitos
OPTIMIZER = SGD() # otimizador SGD
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # quanto é reservado para validação

# Gerando datasets de treino e e teste
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# X_train possui 60000 linhas de valores 28x28 --> reshape para 60000 x 784
# Gera versão final dos datasetes de treino e de teste
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalizando os dados
# Tipicamente, os valores associados a cada pixel são normalizados na faixa [0, 1] 
# (o que significa que a intensidade de cada pixel é dividida por 255, o valor de intensidade máxima). 
# A saída é 10 classes, uma para cada dígito.
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'exemplos de treino')
print(X_test.shape[0], 'exemplos de teste')

# Converte os vetores da class para matrizes binárias das classes
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# Cria as camadas
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape = (RESHAPED,)))
model.add(Activation('relu'))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

# Sumário
model.summary()

# Compila o modelo
model.compile(loss = 'categorical_crossentropy', optimizer = OPTIMIZER, metrics = ['accuracy'])

# Treina o modelo
modelo_v2 = model.fit(X_train, Y_train,
                      batch_size = BATCH_SIZE, 
                      epochs = NB_EPOCH,
                      verbose = VERBOSE, 
                      validation_split = VALIDATION_SPLIT)

# Avalia o modelo com os dados de teste
score = model.evaluate(X_test, Y_test, verbose = VERBOSE)

# Imprime a perda e a acurácia
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 exemplos de treino
# 10000 exemplos de teste
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 1s 12us/step - loss: 1.4993 - accuracy: 0.6277 - val_loss: 0.7663 - val_accuracy: 0.8356
# Epoch 2/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.6061 - accuracy: 0.8505 - val_loss: 0.4583 - val_accuracy: 0.8824
# Epoch 3/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4408 - accuracy: 0.8821 - val_loss: 0.3756 - val_accuracy: 0.8978
# Epoch 4/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3786 - accuracy: 0.8954 - val_loss: 0.3369 - val_accuracy: 0.9049
# Epoch 5/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3442 - accuracy: 0.9030 - val_loss: 0.3115 - val_accuracy: 0.9132
# Epoch 6/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3209 - accuracy: 0.9088 - val_loss: 0.2939 - val_accuracy: 0.9159
# Epoch 7/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.3029 - accuracy: 0.9142 - val_loss: 0.2791 - val_accuracy: 0.9209
# Epoch 8/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2881 - accuracy: 0.9178 - val_loss: 0.2667 - val_accuracy: 0.9233
# Epoch 9/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2760 - accuracy: 0.9210 - val_loss: 0.2567 - val_accuracy: 0.9268
# Epoch 10/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2649 - accuracy: 0.9240 - val_loss: 0.2487 - val_accuracy: 0.9297
# Epoch 11/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2547 - accuracy: 0.9276 - val_loss: 0.2395 - val_accuracy: 0.9323
# Epoch 12/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2452 - accuracy: 0.9300 - val_loss: 0.2321 - val_accuracy: 0.9353
# Epoch 13/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2366 - accuracy: 0.9328 - val_loss: 0.2284 - val_accuracy: 0.9364
# Epoch 14/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2289 - accuracy: 0.9350 - val_loss: 0.2192 - val_accuracy: 0.9386
# Epoch 15/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2212 - accuracy: 0.9370 - val_loss: 0.2121 - val_accuracy: 0.9408
# Epoch 16/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2142 - accuracy: 0.9385 - val_loss: 0.2066 - val_accuracy: 0.9427
# Epoch 17/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2075 - accuracy: 0.9409 - val_loss: 0.2013 - val_accuracy: 0.9448
# Epoch 18/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.2010 - accuracy: 0.9423 - val_loss: 0.1958 - val_accuracy: 0.9462
# Epoch 19/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.1951 - accuracy: 0.9434 - val_loss: 0.1916 - val_accuracy: 0.9472
# Epoch 20/20
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.1897 - accuracy: 0.9452 - val_loss: 0.1871 - val_accuracy: 0.9489
# 10000/10000 [==============================] - 0s 11us/step
#
# Test score: 0.1887594746515155
# Test accuracy: 0.9466999769210815

# %% [markdown]
# # Multilayer Perceptron - Versão 3

# %% [markdown]
# Adicionando Dropout nas camadas ocultas e aumentando o número de epochs

# %% [markdown]
# A segunda melhoria é muito simples. Decidimos retirar aleatoriamente, alguns dos valores propagados dentro das camadas  internas densas (camadas ocultas). Na aprendizagem de máquina, esta é uma forma bem conhecida de regularização. Surpreendentemente, esta ideia de descartar aleatoriamente alguns valores pode melhorar nosso desempenho.

# %% [markdown]
# Dropout é uma técnica onde os neurônios selecionados aleatoriamente são ignorados durante o treinamento. Eles são "abandonados" aleatoriamente. Isto significa que a sua contribuição para a ativação de neurónios é removida temporariamente na passagem para a frente e quaisquer atualizações de peso não são aplicadas ao neurônio na passagem para trás.

# %% [markdown]
# Você pode imaginar que, se os neurônios forem descartados aleatoriamente da rede durante o treinamento, outros neurônios terão de intervir e lidar com a representação necessária para fazer previsões para os neurônios ausentes. Acredita-se que isso resulte em múltiplas representações internas independentes sendo aprendidas pela rede.
#
# O efeito é que a rede se torna menos sensível aos pesos específicos dos neurônios. Isso, por sua vez resulta em uma rede que é capaz de melhorar a generalização e é menos sensível ao overfitting nos dados de treinamento.

# %% [markdown]
# O Dropout é facilmente implementado, por seleção aleatória de neurônios a abandonar, com uma dada probabilidade (por exemplo, 20%) a cada ciclo de atualização de peso. Dropout é usado somente durante o treinamento de um modelo e não é usado ao avaliar a habilidade do modelo.

# %% [markdown]
# Geralmente, usamos valores de 20% - 50% de neurônios para Dropout, com 20% fornecendo um bom ponto de partida. Uma probabilidade muito baixa tem efeito mínimo e um valor muito alto resulta em sub-aprendizagem pela rede. É provável que você obtenha melhor desempenho quando o Dropout é usado em uma rede maior, dando ao modelo mais de uma oportunidade de aprender representações independentes.

# %%
# Import dos pacotes
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import np_utils
import matplotlib.pyplot as plt
# %matplotlib inline

# Garantindo que o resultado pode ser reproduzido
np.random.seed(1671)  

# Parâmetros da rede e do treinamento
NB_EPOCH = 250
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # número de outputs = número de dígitos
OPTIMIZER = SGD() # otimizador SGD
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # quanto é reservado para validação
DROPOUT = 0.3

# Gerando datasets de treino e e teste
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# X_train possui 60000 linhas de valores 28x28 --> reshape para 60000 x 784
# Gera versão final dos datasetes de treino e de teste
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalizando os dados
# Tipicamente, os valores associados a cada pixel são normalizados na faixa [0, 1] 
# (o que significa que a intensidade de cada pixel é dividida por 255, o valor de intensidade máxima). 
# A saída é 10 classes, uma para cada dígito.
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'exemplos de treino')
print(X_test.shape[0], 'exemplos de teste')

# Converte os vetores da class para matrizes binárias das classes
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# Cria as camadas
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

# Sumário
model.summary()

# Compila o modelo
model.compile(loss = 'categorical_crossentropy', optimizer = OPTIMIZER, metrics = ['accuracy'])

# Treina o modelo
modelo_v3 = model.fit(X_train, Y_train,
                      batch_size = BATCH_SIZE, 
                      epochs = NB_EPOCH,
                      verbose = VERBOSE, 
                      validation_split = VALIDATION_SPLIT)

# Avalia o modelo com os dados de teste
score = model.evaluate(X_test, Y_test, verbose = VERBOSE)

# Imprime a perda e a acurácia
print("\nTest score:", score[0])
print('Test accuracy:', score[1])

# Imprime os dados
print(modelo_v3.history.keys())

# Sumariza o modelo para acurácia
plt.plot(modelo_v3.history['accuracy'])
plt.plot(modelo_v3.history['val_accuracy'])
plt.title('Acurácia do Modelo')
plt.ylabel('Acurácia')
plt.xlabel('Epoch')
plt.legend(['Treino', 'Teste'], loc = 'upper left')
plt.show()

# Imprime a evolução de erro do modelo
plt.plot(modelo_v3.history['loss'])
plt.plot(modelo_v3.history['val_loss'])
plt.title('Perda do Modelo')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Treino', 'Teste'], loc = 'upper left')
plt.show()
# Out:
# 60000 exemplos de treino
# 10000 exemplos de teste
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1290
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 1.6719 - accuracy: 0.4667 - val_loss: 0.8720 - val_accuracy: 0.8095
# Epoch 2/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.8992 - accuracy: 0.7243 - val_loss: 0.5214 - val_accuracy: 0.8644
# Epoch 3/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.6838 - accuracy: 0.7914 - val_loss: 0.4178 - val_accuracy: 0.8891
# Epoch 4/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.5847 - accuracy: 0.8206 - val_loss: 0.3668 - val_accuracy: 0.9002
# Epoch 5/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.5258 - accuracy: 0.8414 - val_loss: 0.3341 - val_accuracy: 0.9063
# Epoch 6/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.4846 - accuracy: 0.8580 - val_loss: 0.3103 - val_accuracy: 0.9130
# Epoch 7/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.4510 - accuracy: 0.8671 - val_loss: 0.2920 - val_accuracy: 0.9168
# Epoch 8/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.4251 - accuracy: 0.8734 - val_loss: 0.2764 - val_accuracy: 0.9222
# Epoch 9/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.4066 - accuracy: 0.8792 - val_loss: 0.2644 - val_accuracy: 0.9253
# Epoch 10/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3888 - accuracy: 0.8857 - val_loss: 0.2527 - val_accuracy: 0.9279
# Epoch 11/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3690 - accuracy: 0.8909 - val_loss: 0.2426 - val_accuracy: 0.9305
# Epoch 12/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3565 - accuracy: 0.8947 - val_loss: 0.2338 - val_accuracy: 0.9328
# Epoch 13/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3461 - accuracy: 0.8982 - val_loss: 0.2263 - val_accuracy: 0.9353
# Epoch 14/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3338 - accuracy: 0.9022 - val_loss: 0.2200 - val_accuracy: 0.9365
# Epoch 15/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3227 - accuracy: 0.9049 - val_loss: 0.2135 - val_accuracy: 0.9388
# Epoch 16/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.3127 - accuracy: 0.9079 - val_loss: 0.2068 - val_accuracy: 0.9405
# Epoch 17/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.3033 - accuracy: 0.9118 - val_loss: 0.2014 - val_accuracy: 0.9421
# Epoch 18/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2971 - accuracy: 0.9117 - val_loss: 0.1966 - val_accuracy: 0.9434
# Epoch 19/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2882 - accuracy: 0.9153 - val_loss: 0.1913 - val_accuracy: 0.9456
# Epoch 20/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2842 - accuracy: 0.9171 - val_loss: 0.1875 - val_accuracy: 0.9467
# Epoch 21/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2764 - accuracy: 0.9179 - val_loss: 0.1838 - val_accuracy: 0.9482
# Epoch 22/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2723 - accuracy: 0.9190 - val_loss: 0.1788 - val_accuracy: 0.9495
# Epoch 23/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2647 - accuracy: 0.9222 - val_loss: 0.1757 - val_accuracy: 0.9507
# Epoch 24/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2598 - accuracy: 0.9225 - val_loss: 0.1736 - val_accuracy: 0.9517
# Epoch 25/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2585 - accuracy: 0.9246 - val_loss: 0.1695 - val_accuracy: 0.9529
# Epoch 26/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2510 - accuracy: 0.9268 - val_loss: 0.1666 - val_accuracy: 0.9532
# Epoch 27/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2425 - accuracy: 0.9298 - val_loss: 0.1644 - val_accuracy: 0.9543
# Epoch 28/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2403 - accuracy: 0.9296 - val_loss: 0.1610 - val_accuracy: 0.9546
# Epoch 29/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2382 - accuracy: 0.9301 - val_loss: 0.1583 - val_accuracy: 0.9557
# Epoch 30/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2355 - accuracy: 0.9304 - val_loss: 0.1560 - val_accuracy: 0.9567
# Epoch 31/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2293 - accuracy: 0.9329 - val_loss: 0.1535 - val_accuracy: 0.9573
# Epoch 32/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2247 - accuracy: 0.9331 - val_loss: 0.1517 - val_accuracy: 0.9572
# Epoch 33/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2236 - accuracy: 0.9339 - val_loss: 0.1492 - val_accuracy: 0.9574
# Epoch 34/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2196 - accuracy: 0.9346 - val_loss: 0.1476 - val_accuracy: 0.9574
# Epoch 35/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2181 - accuracy: 0.9358 - val_loss: 0.1452 - val_accuracy: 0.9588
# Epoch 36/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2151 - accuracy: 0.9369 - val_loss: 0.1440 - val_accuracy: 0.9588
# Epoch 37/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2097 - accuracy: 0.9376 - val_loss: 0.1421 - val_accuracy: 0.9592
# Epoch 38/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2089 - accuracy: 0.9377 - val_loss: 0.1405 - val_accuracy: 0.9593
# Epoch 39/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2067 - accuracy: 0.9392 - val_loss: 0.1391 - val_accuracy: 0.9599
# Epoch 40/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.2019 - accuracy: 0.9402 - val_loss: 0.1380 - val_accuracy: 0.9603
# Epoch 41/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.2013 - accuracy: 0.9408 - val_loss: 0.1355 - val_accuracy: 0.9611
# Epoch 42/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1974 - accuracy: 0.9413 - val_loss: 0.1337 - val_accuracy: 0.9619
# Epoch 43/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1954 - accuracy: 0.9422 - val_loss: 0.1322 - val_accuracy: 0.9617
# Epoch 44/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1926 - accuracy: 0.9431 - val_loss: 0.1313 - val_accuracy: 0.9620
# Epoch 45/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1930 - accuracy: 0.9427 - val_loss: 0.1297 - val_accuracy: 0.9628
# Epoch 46/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1871 - accuracy: 0.9447 - val_loss: 0.1290 - val_accuracy: 0.9628
# Epoch 47/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1832 - accuracy: 0.9454 - val_loss: 0.1273 - val_accuracy: 0.9632
# Epoch 48/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1835 - accuracy: 0.9451 - val_loss: 0.1271 - val_accuracy: 0.9629
# Epoch 49/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1814 - accuracy: 0.9465 - val_loss: 0.1253 - val_accuracy: 0.9636
# Epoch 50/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1808 - accuracy: 0.9460 - val_loss: 0.1243 - val_accuracy: 0.9632
# Epoch 51/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1804 - accuracy: 0.9460 - val_loss: 0.1226 - val_accuracy: 0.9641
# Epoch 52/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1800 - accuracy: 0.9456 - val_loss: 0.1222 - val_accuracy: 0.9641
# Epoch 53/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1754 - accuracy: 0.9482 - val_loss: 0.1207 - val_accuracy: 0.9645
# Epoch 54/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1750 - accuracy: 0.9478 - val_loss: 0.1197 - val_accuracy: 0.9653
# Epoch 55/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1700 - accuracy: 0.9502 - val_loss: 0.1193 - val_accuracy: 0.9653
# Epoch 56/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1710 - accuracy: 0.9487 - val_loss: 0.1185 - val_accuracy: 0.9654
# Epoch 57/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1697 - accuracy: 0.9501 - val_loss: 0.1172 - val_accuracy: 0.9657
# Epoch 58/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1658 - accuracy: 0.9506 - val_loss: 0.1163 - val_accuracy: 0.9657
# Epoch 59/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1669 - accuracy: 0.9500 - val_loss: 0.1158 - val_accuracy: 0.9661
# Epoch 60/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1639 - accuracy: 0.9517 - val_loss: 0.1145 - val_accuracy: 0.9669
# Epoch 61/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1596 - accuracy: 0.9524 - val_loss: 0.1135 - val_accuracy: 0.9668
# Epoch 62/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1611 - accuracy: 0.9519 - val_loss: 0.1131 - val_accuracy: 0.9668
# Epoch 63/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1581 - accuracy: 0.9537 - val_loss: 0.1123 - val_accuracy: 0.9672
# Epoch 64/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1569 - accuracy: 0.9538 - val_loss: 0.1120 - val_accuracy: 0.9672
# Epoch 65/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1568 - accuracy: 0.9538 - val_loss: 0.1114 - val_accuracy: 0.9673
# Epoch 66/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1550 - accuracy: 0.9544 - val_loss: 0.1108 - val_accuracy: 0.9673
# Epoch 67/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1548 - accuracy: 0.9539 - val_loss: 0.1100 - val_accuracy: 0.9678
# Epoch 68/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1525 - accuracy: 0.9544 - val_loss: 0.1085 - val_accuracy: 0.9686
# Epoch 69/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1509 - accuracy: 0.9546 - val_loss: 0.1082 - val_accuracy: 0.9677
# Epoch 70/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1512 - accuracy: 0.9557 - val_loss: 0.1073 - val_accuracy: 0.9685
# Epoch 71/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1485 - accuracy: 0.9567 - val_loss: 0.1072 - val_accuracy: 0.9688
# Epoch 72/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1467 - accuracy: 0.9562 - val_loss: 0.1062 - val_accuracy: 0.9688
# Epoch 73/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1473 - accuracy: 0.9557 - val_loss: 0.1055 - val_accuracy: 0.9693
# Epoch 74/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1430 - accuracy: 0.9568 - val_loss: 0.1054 - val_accuracy: 0.9696
# Epoch 75/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1440 - accuracy: 0.9571 - val_loss: 0.1050 - val_accuracy: 0.9690
# Epoch 76/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1456 - accuracy: 0.9569 - val_loss: 0.1044 - val_accuracy: 0.9695
# Epoch 77/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1422 - accuracy: 0.9571 - val_loss: 0.1040 - val_accuracy: 0.9695
# Epoch 78/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1402 - accuracy: 0.9584 - val_loss: 0.1032 - val_accuracy: 0.9696
# Epoch 79/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1406 - accuracy: 0.9574 - val_loss: 0.1035 - val_accuracy: 0.9695
# Epoch 80/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1407 - accuracy: 0.9580 - val_loss: 0.1034 - val_accuracy: 0.9689
# Epoch 81/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1374 - accuracy: 0.9588 - val_loss: 0.1022 - val_accuracy: 0.9700
# Epoch 82/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1358 - accuracy: 0.9591 - val_loss: 0.1015 - val_accuracy: 0.9700
# Epoch 83/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1349 - accuracy: 0.9596 - val_loss: 0.1011 - val_accuracy: 0.9709
# Epoch 84/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1366 - accuracy: 0.9590 - val_loss: 0.1009 - val_accuracy: 0.9703
# Epoch 85/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1345 - accuracy: 0.9594 - val_loss: 0.1002 - val_accuracy: 0.9702
# Epoch 86/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1310 - accuracy: 0.9602 - val_loss: 0.1002 - val_accuracy: 0.9701
# Epoch 87/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1310 - accuracy: 0.9602 - val_loss: 0.0995 - val_accuracy: 0.9712
# Epoch 88/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1294 - accuracy: 0.9611 - val_loss: 0.0994 - val_accuracy: 0.9705
# Epoch 89/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1313 - accuracy: 0.9602 - val_loss: 0.0983 - val_accuracy: 0.9706
# Epoch 90/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1285 - accuracy: 0.9611 - val_loss: 0.0984 - val_accuracy: 0.9710
# Epoch 91/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.1279 - accuracy: 0.9609 - val_loss: 0.0977 - val_accuracy: 0.9714
# Epoch 92/250
# 48000/48000 [==============================] - 1s 15us/step - loss: 0.1299 - accuracy: 0.9606 - val_loss: 0.0973 - val_accuracy: 0.9718
# Epoch 93/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.1257 - accuracy: 0.9626 - val_loss: 0.0967 - val_accuracy: 0.9712
# Epoch 94/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1252 - accuracy: 0.9624 - val_loss: 0.0964 - val_accuracy: 0.9715
# Epoch 95/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1273 - accuracy: 0.9621 - val_loss: 0.0967 - val_accuracy: 0.9712
# Epoch 96/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1263 - accuracy: 0.9625 - val_loss: 0.0967 - val_accuracy: 0.9714
# Epoch 97/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1217 - accuracy: 0.9633 - val_loss: 0.0960 - val_accuracy: 0.9720
# Epoch 98/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1228 - accuracy: 0.9627 - val_loss: 0.0956 - val_accuracy: 0.9720
# Epoch 99/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1194 - accuracy: 0.9640 - val_loss: 0.0957 - val_accuracy: 0.9719
# Epoch 100/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1222 - accuracy: 0.9632 - val_loss: 0.0953 - val_accuracy: 0.9718
# Epoch 101/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1229 - accuracy: 0.9633 - val_loss: 0.0951 - val_accuracy: 0.9712
# Epoch 102/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1174 - accuracy: 0.9648 - val_loss: 0.0947 - val_accuracy: 0.9719
# Epoch 103/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1197 - accuracy: 0.9637 - val_loss: 0.0943 - val_accuracy: 0.9721
# Epoch 104/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.1168 - accuracy: 0.9658 - val_loss: 0.0938 - val_accuracy: 0.9719
# Epoch 105/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1175 - accuracy: 0.9650 - val_loss: 0.0931 - val_accuracy: 0.9722
# Epoch 106/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1144 - accuracy: 0.9658 - val_loss: 0.0935 - val_accuracy: 0.9718
# Epoch 107/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1154 - accuracy: 0.9648 - val_loss: 0.0939 - val_accuracy: 0.9717
# Epoch 108/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1132 - accuracy: 0.9661 - val_loss: 0.0927 - val_accuracy: 0.9722
# Epoch 109/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1129 - accuracy: 0.9663 - val_loss: 0.0927 - val_accuracy: 0.9722
# Epoch 110/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1151 - accuracy: 0.9656 - val_loss: 0.0917 - val_accuracy: 0.9723
# Epoch 111/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1166 - accuracy: 0.9648 - val_loss: 0.0918 - val_accuracy: 0.9727
# Epoch 112/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1123 - accuracy: 0.9668 - val_loss: 0.0915 - val_accuracy: 0.9726
# Epoch 113/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1127 - accuracy: 0.9659 - val_loss: 0.0920 - val_accuracy: 0.9725
# Epoch 114/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1119 - accuracy: 0.9662 - val_loss: 0.0909 - val_accuracy: 0.9730
# Epoch 115/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1106 - accuracy: 0.9664 - val_loss: 0.0908 - val_accuracy: 0.9729
# Epoch 116/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1110 - accuracy: 0.9659 - val_loss: 0.0912 - val_accuracy: 0.9729
# Epoch 117/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.1088 - accuracy: 0.9670 - val_loss: 0.0909 - val_accuracy: 0.9729
# Epoch 118/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1087 - accuracy: 0.9669 - val_loss: 0.0900 - val_accuracy: 0.9723
# Epoch 119/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1082 - accuracy: 0.9672 - val_loss: 0.0904 - val_accuracy: 0.9732
# Epoch 120/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1066 - accuracy: 0.9669 - val_loss: 0.0898 - val_accuracy: 0.9728
# Epoch 121/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1083 - accuracy: 0.9670 - val_loss: 0.0907 - val_accuracy: 0.9728
# Epoch 122/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1039 - accuracy: 0.9684 - val_loss: 0.0894 - val_accuracy: 0.9729
# Epoch 123/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1061 - accuracy: 0.9685 - val_loss: 0.0889 - val_accuracy: 0.9733
# Epoch 124/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1057 - accuracy: 0.9685 - val_loss: 0.0890 - val_accuracy: 0.9735
# Epoch 125/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1059 - accuracy: 0.9681 - val_loss: 0.0884 - val_accuracy: 0.9737
# Epoch 126/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1049 - accuracy: 0.9681 - val_loss: 0.0889 - val_accuracy: 0.9736
# Epoch 127/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1044 - accuracy: 0.9683 - val_loss: 0.0888 - val_accuracy: 0.9737
# Epoch 128/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1041 - accuracy: 0.9685 - val_loss: 0.0880 - val_accuracy: 0.9738
# Epoch 129/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1053 - accuracy: 0.9688 - val_loss: 0.0883 - val_accuracy: 0.9739
# Epoch 130/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1038 - accuracy: 0.9680 - val_loss: 0.0881 - val_accuracy: 0.9743
# Epoch 131/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1016 - accuracy: 0.9699 - val_loss: 0.0873 - val_accuracy: 0.9742
# Epoch 132/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1003 - accuracy: 0.9691 - val_loss: 0.0875 - val_accuracy: 0.9743
# Epoch 133/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0991 - accuracy: 0.9698 - val_loss: 0.0875 - val_accuracy: 0.9739
# Epoch 134/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.1014 - accuracy: 0.9692 - val_loss: 0.0875 - val_accuracy: 0.9737
# Epoch 135/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0987 - accuracy: 0.9690 - val_loss: 0.0876 - val_accuracy: 0.9737
# Epoch 136/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0972 - accuracy: 0.9706 - val_loss: 0.0868 - val_accuracy: 0.9737
# Epoch 137/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0963 - accuracy: 0.9708 - val_loss: 0.0871 - val_accuracy: 0.9743
# Epoch 138/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0979 - accuracy: 0.9707 - val_loss: 0.0862 - val_accuracy: 0.9741
# Epoch 139/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0994 - accuracy: 0.9696 - val_loss: 0.0864 - val_accuracy: 0.9742
# Epoch 140/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0965 - accuracy: 0.9714 - val_loss: 0.0862 - val_accuracy: 0.9745
# Epoch 141/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0971 - accuracy: 0.9705 - val_loss: 0.0855 - val_accuracy: 0.9743
# Epoch 142/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0961 - accuracy: 0.9708 - val_loss: 0.0865 - val_accuracy: 0.9739
# Epoch 143/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0955 - accuracy: 0.9707 - val_loss: 0.0850 - val_accuracy: 0.9743
# Epoch 144/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0930 - accuracy: 0.9710 - val_loss: 0.0856 - val_accuracy: 0.9745
# Epoch 145/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0933 - accuracy: 0.9709 - val_loss: 0.0853 - val_accuracy: 0.9747
# Epoch 146/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0948 - accuracy: 0.9713 - val_loss: 0.0848 - val_accuracy: 0.9745
# Epoch 147/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0946 - accuracy: 0.9711 - val_loss: 0.0848 - val_accuracy: 0.9743
# Epoch 148/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0954 - accuracy: 0.9705 - val_loss: 0.0850 - val_accuracy: 0.9744
# Epoch 149/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0929 - accuracy: 0.9712 - val_loss: 0.0848 - val_accuracy: 0.9746
# Epoch 150/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0925 - accuracy: 0.9714 - val_loss: 0.0846 - val_accuracy: 0.9752
# Epoch 151/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0924 - accuracy: 0.9722 - val_loss: 0.0851 - val_accuracy: 0.9747
# Epoch 152/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0938 - accuracy: 0.9715 - val_loss: 0.0845 - val_accuracy: 0.9747
# Epoch 153/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0907 - accuracy: 0.9723 - val_loss: 0.0837 - val_accuracy: 0.9749
# Epoch 154/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0907 - accuracy: 0.9722 - val_loss: 0.0840 - val_accuracy: 0.9744
# Epoch 155/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0907 - accuracy: 0.9726 - val_loss: 0.0841 - val_accuracy: 0.9749
# Epoch 156/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0892 - accuracy: 0.9731 - val_loss: 0.0839 - val_accuracy: 0.9747
# Epoch 157/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0891 - accuracy: 0.9724 - val_loss: 0.0838 - val_accuracy: 0.9745
# Epoch 158/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0880 - accuracy: 0.9727 - val_loss: 0.0843 - val_accuracy: 0.9752
# Epoch 159/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0876 - accuracy: 0.9729 - val_loss: 0.0834 - val_accuracy: 0.9753
# Epoch 160/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0866 - accuracy: 0.9740 - val_loss: 0.0837 - val_accuracy: 0.9754
# Epoch 161/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0887 - accuracy: 0.9717 - val_loss: 0.0835 - val_accuracy: 0.9752
# Epoch 162/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0872 - accuracy: 0.9737 - val_loss: 0.0833 - val_accuracy: 0.9753
# Epoch 163/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0874 - accuracy: 0.9734 - val_loss: 0.0835 - val_accuracy: 0.9752
# Epoch 164/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0858 - accuracy: 0.9734 - val_loss: 0.0834 - val_accuracy: 0.9753
# Epoch 165/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0869 - accuracy: 0.9724 - val_loss: 0.0831 - val_accuracy: 0.9748
# Epoch 166/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0882 - accuracy: 0.9733 - val_loss: 0.0827 - val_accuracy: 0.9756
# Epoch 167/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0866 - accuracy: 0.9727 - val_loss: 0.0824 - val_accuracy: 0.9753
# Epoch 168/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0849 - accuracy: 0.9736 - val_loss: 0.0823 - val_accuracy: 0.9758
# Epoch 169/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0845 - accuracy: 0.9735 - val_loss: 0.0824 - val_accuracy: 0.9754
# Epoch 170/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0855 - accuracy: 0.9734 - val_loss: 0.0820 - val_accuracy: 0.9754
# Epoch 171/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0865 - accuracy: 0.9731 - val_loss: 0.0820 - val_accuracy: 0.9757
# Epoch 172/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0834 - accuracy: 0.9745 - val_loss: 0.0825 - val_accuracy: 0.9752
# Epoch 173/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0856 - accuracy: 0.9745 - val_loss: 0.0824 - val_accuracy: 0.9759
# Epoch 174/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0845 - accuracy: 0.9734 - val_loss: 0.0818 - val_accuracy: 0.9757
# Epoch 175/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.0859 - accuracy: 0.9733 - val_loss: 0.0820 - val_accuracy: 0.9761
# Epoch 176/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0830 - accuracy: 0.9739 - val_loss: 0.0824 - val_accuracy: 0.9766
# Epoch 177/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0823 - accuracy: 0.9748 - val_loss: 0.0821 - val_accuracy: 0.9759
# Epoch 178/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0820 - accuracy: 0.9746 - val_loss: 0.0818 - val_accuracy: 0.9758
# Epoch 179/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0803 - accuracy: 0.9757 - val_loss: 0.0817 - val_accuracy: 0.9761
# Epoch 180/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.0820 - accuracy: 0.9754 - val_loss: 0.0822 - val_accuracy: 0.9762
# Epoch 181/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.0811 - accuracy: 0.9751 - val_loss: 0.0820 - val_accuracy: 0.9761
# Epoch 182/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0804 - accuracy: 0.9743 - val_loss: 0.0821 - val_accuracy: 0.9761
# Epoch 183/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.0804 - accuracy: 0.9754 - val_loss: 0.0817 - val_accuracy: 0.9764
# Epoch 184/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0820 - accuracy: 0.9751 - val_loss: 0.0810 - val_accuracy: 0.9759
# Epoch 185/250
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.0795 - accuracy: 0.9754 - val_loss: 0.0817 - val_accuracy: 0.9758
# Epoch 186/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0782 - accuracy: 0.9754 - val_loss: 0.0815 - val_accuracy: 0.9758
# Epoch 187/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0780 - accuracy: 0.9758 - val_loss: 0.0814 - val_accuracy: 0.9773
# Epoch 188/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0779 - accuracy: 0.9755 - val_loss: 0.0808 - val_accuracy: 0.9767
# Epoch 189/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0802 - accuracy: 0.9755 - val_loss: 0.0812 - val_accuracy: 0.9765
# Epoch 190/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0784 - accuracy: 0.9760 - val_loss: 0.0813 - val_accuracy: 0.9759
# Epoch 191/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0748 - accuracy: 0.9769 - val_loss: 0.0815 - val_accuracy: 0.9767
# Epoch 192/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0769 - accuracy: 0.9759 - val_loss: 0.0808 - val_accuracy: 0.9766
# Epoch 193/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0794 - accuracy: 0.9756 - val_loss: 0.0810 - val_accuracy: 0.9764
# Epoch 194/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0764 - accuracy: 0.9759 - val_loss: 0.0807 - val_accuracy: 0.9766
# Epoch 195/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0753 - accuracy: 0.9773 - val_loss: 0.0808 - val_accuracy: 0.9768
# Epoch 196/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0751 - accuracy: 0.9759 - val_loss: 0.0811 - val_accuracy: 0.9762
# Epoch 197/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0754 - accuracy: 0.9762 - val_loss: 0.0806 - val_accuracy: 0.9763
# Epoch 198/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0780 - accuracy: 0.9751 - val_loss: 0.0811 - val_accuracy: 0.9762
# Epoch 199/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0738 - accuracy: 0.9765 - val_loss: 0.0806 - val_accuracy: 0.9766
# Epoch 200/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0762 - accuracy: 0.9762 - val_loss: 0.0805 - val_accuracy: 0.9766
# Epoch 201/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0744 - accuracy: 0.9765 - val_loss: 0.0803 - val_accuracy: 0.9768
# Epoch 202/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0724 - accuracy: 0.9781 - val_loss: 0.0804 - val_accuracy: 0.9767
# Epoch 203/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0721 - accuracy: 0.9780 - val_loss: 0.0803 - val_accuracy: 0.9763
# Epoch 204/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0755 - accuracy: 0.9770 - val_loss: 0.0806 - val_accuracy: 0.9769
# Epoch 205/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0750 - accuracy: 0.9772 - val_loss: 0.0797 - val_accuracy: 0.9771
# Epoch 206/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0757 - accuracy: 0.9772 - val_loss: 0.0799 - val_accuracy: 0.9769
# Epoch 207/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0729 - accuracy: 0.9768 - val_loss: 0.0807 - val_accuracy: 0.9773
# Epoch 208/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0711 - accuracy: 0.9773 - val_loss: 0.0807 - val_accuracy: 0.9769
# Epoch 209/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0731 - accuracy: 0.9769 - val_loss: 0.0801 - val_accuracy: 0.9765
# Epoch 210/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0736 - accuracy: 0.9773 - val_loss: 0.0800 - val_accuracy: 0.9768
# Epoch 211/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0742 - accuracy: 0.9765 - val_loss: 0.0805 - val_accuracy: 0.9768
# Epoch 212/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0738 - accuracy: 0.9766 - val_loss: 0.0799 - val_accuracy: 0.9768
# Epoch 213/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0716 - accuracy: 0.9767 - val_loss: 0.0796 - val_accuracy: 0.9768
# Epoch 214/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0727 - accuracy: 0.9775 - val_loss: 0.0799 - val_accuracy: 0.9773
# Epoch 215/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0712 - accuracy: 0.9773 - val_loss: 0.0794 - val_accuracy: 0.9772
# Epoch 216/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0712 - accuracy: 0.9770 - val_loss: 0.0798 - val_accuracy: 0.9772
# Epoch 217/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0713 - accuracy: 0.9782 - val_loss: 0.0797 - val_accuracy: 0.9774
# Epoch 218/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0696 - accuracy: 0.9780 - val_loss: 0.0801 - val_accuracy: 0.9766
# Epoch 219/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0733 - accuracy: 0.9771 - val_loss: 0.0791 - val_accuracy: 0.9775
# Epoch 220/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0700 - accuracy: 0.9778 - val_loss: 0.0789 - val_accuracy: 0.9767
# Epoch 221/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0701 - accuracy: 0.9781 - val_loss: 0.0789 - val_accuracy: 0.9772
# Epoch 222/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0714 - accuracy: 0.9776 - val_loss: 0.0796 - val_accuracy: 0.9765
# Epoch 223/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0700 - accuracy: 0.9785 - val_loss: 0.0790 - val_accuracy: 0.9766
# Epoch 224/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0681 - accuracy: 0.9779 - val_loss: 0.0788 - val_accuracy: 0.9770
# Epoch 225/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0701 - accuracy: 0.9781 - val_loss: 0.0787 - val_accuracy: 0.9773
# Epoch 226/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0685 - accuracy: 0.9782 - val_loss: 0.0790 - val_accuracy: 0.9768
# Epoch 227/250
# 48000/48000 [==============================] - 1s 13us/step - loss: 0.0686 - accuracy: 0.9789 - val_loss: 0.0789 - val_accuracy: 0.9772
# Epoch 228/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0684 - accuracy: 0.9783 - val_loss: 0.0788 - val_accuracy: 0.9776
# Epoch 229/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0670 - accuracy: 0.9797 - val_loss: 0.0792 - val_accuracy: 0.9770
# Epoch 230/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0671 - accuracy: 0.9794 - val_loss: 0.0792 - val_accuracy: 0.9772
# Epoch 231/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0673 - accuracy: 0.9789 - val_loss: 0.0789 - val_accuracy: 0.9775
# Epoch 232/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0666 - accuracy: 0.9787 - val_loss: 0.0786 - val_accuracy: 0.9773
# Epoch 233/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0651 - accuracy: 0.9794 - val_loss: 0.0781 - val_accuracy: 0.9774
# Epoch 234/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0669 - accuracy: 0.9789 - val_loss: 0.0779 - val_accuracy: 0.9778
# Epoch 235/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0673 - accuracy: 0.9789 - val_loss: 0.0776 - val_accuracy: 0.9776
# Epoch 236/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0663 - accuracy: 0.9797 - val_loss: 0.0791 - val_accuracy: 0.9772
# Epoch 237/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0652 - accuracy: 0.9799 - val_loss: 0.0786 - val_accuracy: 0.9777
# Epoch 238/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0656 - accuracy: 0.9796 - val_loss: 0.0788 - val_accuracy: 0.9775
# Epoch 239/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0660 - accuracy: 0.9789 - val_loss: 0.0789 - val_accuracy: 0.9775
# Epoch 240/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0662 - accuracy: 0.9798 - val_loss: 0.0781 - val_accuracy: 0.9778
# Epoch 241/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0650 - accuracy: 0.9790 - val_loss: 0.0780 - val_accuracy: 0.9771
# Epoch 242/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0663 - accuracy: 0.9794 - val_loss: 0.0783 - val_accuracy: 0.9775
# Epoch 243/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0644 - accuracy: 0.9794 - val_loss: 0.0782 - val_accuracy: 0.9772
# Epoch 244/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0636 - accuracy: 0.9794 - val_loss: 0.0784 - val_accuracy: 0.9769
# Epoch 245/250
# 48000/48000 [==============================] - 1s 12us/step - loss: 0.0643 - accuracy: 0.9799 - val_loss: 0.0787 - val_accuracy: 0.9772
# Epoch 246/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0656 - accuracy: 0.9791 - val_loss: 0.0785 - val_accuracy: 0.9776
# Epoch 247/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0632 - accuracy: 0.9801 - val_loss: 0.0793 - val_accuracy: 0.9778
# Epoch 248/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0626 - accuracy: 0.9808 - val_loss: 0.0790 - val_accuracy: 0.9770
# Epoch 249/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0638 - accuracy: 0.9799 - val_loss: 0.0785 - val_accuracy: 0.9772
# Epoch 250/250
# 48000/48000 [==============================] - 1s 11us/step - loss: 0.0638 - accuracy: 0.9803 - val_loss: 0.0785 - val_accuracy: 0.9769
# 10000/10000 [==============================] - 0s 12us/step
#
# Test score: 0.07272253520364175
# Test accuracy: 0.9772999882698059
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
modelo_v3.history
# Out:
# {'val_loss': [0.871999571164449,
#   0.521393892288208,
#   0.4177523496945699,
#   0.366813898007075,
#   0.334132959206899,
#   0.3102873472372691,
#   0.291970361550649,
#   0.27642452088991804,
#   0.2644186542828878,
#   0.25272273087501523,
#   0.24256080039342245,
#   0.23384717671076458,
#   0.22629604335625966,
#   0.219956143339475,
#   0.21347696204980215,
#   0.20682338778177897,
#   0.20141988857587179,
#   0.19655210212866464,
#   0.19131107012430826,
#   0.1875295756260554,
#   0.183781037569046,
#   0.1788161812822024,
#   0.1756703089872996,
#   0.17358675563335418,
#   0.1695327783425649,
#   0.16662849358717602,
#   0.16444878935813903,
#   0.1610063178539276,
#   0.1583196446299553,
#   0.1559868117570877,
#   0.15351283091306686,
#   0.15172955838839214,
#   0.14920109055439632,
#   0.1476012070775032,
#   0.14518754879633586,
#   0.14400072451432547,
#   0.14210421262184778,
#   0.14050010921557746,
#   0.13913086926937104,
#   0.13798205932974816,
#   0.13554945316910744,
#   0.13374143987894058,
#   0.13215290693442028,
#   0.13125316510597865,
#   0.12966657936573028,
#   0.12896193359295527,
#   0.12731600893537204,
#   0.12710221207141875,
#   0.12528126028180123,
#   0.12429961670438448,
#   0.12264348325133324,
#   0.12224031128485997,
#   0.12073187904556593,
#   0.11968625209728877,
#   0.11932881804307302,
#   0.11853465887904167,
#   0.11721504775683085,
#   0.11632991524537405,
#   0.11575032306710879,
#   0.11451062297821045,
#   0.11347799201806387,
#   0.11311590509613355,
#   0.11225592822829883,
#   0.11204802170395851,
#   0.11141155101855596,
#   0.11080316623051961,
#   0.1100211744705836,
#   0.10854206881920496,
#   0.10816381444533665,
#   0.10730853312214216,
#   0.10721798832217852,
#   0.1062190254231294,
#   0.10546970680356026,
#   0.10541149657964706,
#   0.10498425792654355,
#   0.10435533172885576,
#   0.10398757378260294,
#   0.1032457653582096,
#   0.10351066269477209,
#   0.10340700980027517,
#   0.10217260386546453,
#   0.10149867176512876,
#   0.10114230520526568,
#   0.1008902683854103,
#   0.10016246782243252,
#   0.10017216549317041,
#   0.09950701134403547,
#   0.09935394202669462,
#   0.09831198950608572,
#   0.09839140337208907,
#   0.09773367715875307,
#   0.09725434537231922,
#   0.09670438240468503,
#   0.0964294031659762,
#   0.09665178030232588,
#   0.09674161565303803,
#   0.09595397659142813,
#   0.09557876309752464,
#   0.09565312991539637,
#   0.09525139264265696,
#   0.0951430862993002,
#   0.09473571855823198,
#   0.09431856875618298,
#   0.09383948795000711,
#   0.09307371932268142,
#   0.09351328938702742,
#   0.09394393743077914,
#   0.09269869487981001,
#   0.09266713130970795,
#   0.09171983480453491,
#   0.09179124609629313,
#   0.09148975134889285,
#   0.09198786441981792,
#   0.09094709227482478,
#   0.09078665681680044,
#   0.09115670782327652,
#   0.09086098858217398,
#   0.08995543293158213,
#   0.09042837238311767,
#   0.0897579378883044,
#   0.09070249961813291,
#   0.08939326633512974,
#   0.08891990407804648,
#   0.08895500252644221,
#   0.08844711043437321,
#   0.08890153580407302,
#   0.08883088102191687,
#   0.08797655034561952,
#   0.08828698416550954,
#   0.08812591836353142,
#   0.08726821153114239,
#   0.08746123513579368,
#   0.08745246188342572,
#   0.0874534050921599,
#   0.08760325860480467,
#   0.0867525751615564,
#   0.0871443738763531,
#   0.08624127382040024,
#   0.08640982583910227,
#   0.08618162447959185,
#   0.08546229117612043,
#   0.08653614789744218,
#   0.0850354366923372,
#   0.08560640543450912,
#   0.08530568268398443,
#   0.08479671497891346,
#   0.08481078511973222,
#   0.08504357348630825,
#   0.08484776891767978,
#   0.08460316480944555,
#   0.08514290590832631,
#   0.0844974313179652,
#   0.08373664919535319,
#   0.0840012474283576,
#   0.0841077196498712,
#   0.08390415182709694,
#   0.08381083021809657,
#   0.08425166887044906,
#   0.08341817345966895,
#   0.08373044682045777,
#   0.0834661357825001,
#   0.08333617933094502,
#   0.0834838119794925,
#   0.08338604325304429,
#   0.08306602309892575,
#   0.08268544911841551,
#   0.08242951378971339,
#   0.08229198147108158,
#   0.08242523265381654,
#   0.08203628928462664,
#   0.08196946398168803,
#   0.08245639952768882,
#   0.08241042739152908,
#   0.08180828765034676,
#   0.08201088424772024,
#   0.08240918418516716,
#   0.08210501572489738,
#   0.08182147379467884,
#   0.08167593588183324,
#   0.08216000298162301,
#   0.08203366198639075,
#   0.08205978883554538,
#   0.0816541764959693,
#   0.08099196362743775,
#   0.08170367256800333,
#   0.08152422965317964,
#   0.08136748912433783,
#   0.08083695046852032,
#   0.08117236944039663,
#   0.08127109279980262,
#   0.08151057178278764,
#   0.08082127304375172,
#   0.08104372343669335,
#   0.08067285862316688,
#   0.08076616988827785,
#   0.08112569032857815,
#   0.08064376109590134,
#   0.08109351912140847,
#   0.08058689156795541,
#   0.08046470529461901,
#   0.08033855028326313,
#   0.08042616600791613,
#   0.08025285766770442,
#   0.08059642961000403,
#   0.07971639031171798,
#   0.0799047132184108,
#   0.08070861812432607,
#   0.08073358227560917,
#   0.0801022519953549,
#   0.07997565781325101,
#   0.08047341053684552,
#   0.07989382061113914,
#   0.07960958785067002,
#   0.0798661517004172,
#   0.07940204356610775,
#   0.07976739821210503,
#   0.07971468136956295,
#   0.0800717469677329,
#   0.07909792777771751,
#   0.07891608283668756,
#   0.07887482927491267,
#   0.07957956936458746,
#   0.07897949682672818,
#   0.0787984209333857,
#   0.0786894328246514,
#   0.07903080170104901,
#   0.07890559161702791,
#   0.07882043961435556,
#   0.0792345328728358,
#   0.07916343415280183,
#   0.07886880462244153,
#   0.07864963394403458,
#   0.07812097280224164,
#   0.07788025477528572,
#   0.07760061508417129,
#   0.07909349785000086,
#   0.07860834622383117,
#   0.0788097498814265,
#   0.07893218853200476,
#   0.07810796315222979,
#   0.07799393801391125,
#   0.07831159827361504,
#   0.07821189290533463,
#   0.078396965538462,
#   0.07866764760638277,
#   0.078483530467997,
#   0.07933228862037262,
#   0.0789734168301026,
#   0.0785114310408632,
#   0.07845981373389561],
#  'val_accuracy': [0.809499979019165,
#   0.8644166588783264,
#   0.8890833258628845,
#   0.9001666903495789,
#   0.906333327293396,
#   0.9129999876022339,
#   0.9168333411216736,
#   0.922166645526886,
#   0.9253333210945129,
#   0.9279166460037231,
#   0.9304999709129333,
#   0.9328333139419556,
#   0.9353333115577698,
#   0.9365000128746033,
#   0.9387500286102295,
#   0.940500020980835,
#   0.9420833587646484,
#   0.9434166550636292,
#   0.9455833435058594,
#   0.9467499852180481,
#   0.9481666684150696,
#   0.9495000243186951,
#   0.9506666660308838,
#   0.9516666531562805,
#   0.95291668176651,
#   0.953166663646698,
#   0.9543333053588867,
#   0.9545833468437195,
#   0.9557499885559082,
#   0.9567499756813049,
#   0.9573333263397217,
#   0.9572499990463257,
#   0.9574166536331177,
#   0.9574166536331177,
#   0.9587500095367432,
#   0.9588333368301392,
#   0.9592499732971191,
#   0.9593333601951599,
#   0.9599166512489319,
#   0.9602500200271606,
#   0.9610833525657654,
#   0.9619166851043701,
#   0.9617499709129333,
#   0.9620000123977661,
#   0.9628333449363708,
#   0.9628333449363708,
#   0.9631666541099548,
#   0.9629166722297668,
#   0.9635833501815796,
#   0.9632499814033508,
#   0.9640833139419556,
#   0.9640833139419556,
#   0.9645000100135803,
#   0.9653333425521851,
#   0.9653333425521851,
#   0.965416669845581,
#   0.965749979019165,
#   0.965749979019165,
#   0.9660833477973938,
#   0.9669166803359985,
#   0.9668333530426025,
#   0.9668333530426025,
#   0.9672499895095825,
#   0.9672499895095825,
#   0.9673333168029785,
#   0.9673333168029785,
#   0.9677500128746033,
#   0.968583345413208,
#   0.9676666855812073,
#   0.968500018119812,
#   0.96875,
#   0.968833327293396,
#   0.9693333506584167,
#   0.9695833325386047,
#   0.968999981880188,
#   0.9695000052452087,
#   0.9695000052452087,
#   0.9695833325386047,
#   0.9695000052452087,
#   0.968916654586792,
#   0.9700000286102295,
#   0.9700000286102295,
#   0.9709166884422302,
#   0.9703333377838135,
#   0.9701666831970215,
#   0.9700833559036255,
#   0.9712499976158142,
#   0.9704999923706055,
#   0.9705833196640015,
#   0.9710000157356262,
#   0.9714166522026062,
#   0.971750020980835,
#   0.9711666703224182,
#   0.9714999794960022,
#   0.9712499976158142,
#   0.9714166522026062,
#   0.972000002861023,
#   0.972000002861023,
#   0.971916675567627,
#   0.971833348274231,
#   0.9711666703224182,
#   0.971916675567627,
#   0.972083330154419,
#   0.971916675567627,
#   0.9721666574478149,
#   0.971750020980835,
#   0.971666693687439,
#   0.9722499847412109,
#   0.9721666574478149,
#   0.9723333120346069,
#   0.9726666808128357,
#   0.9725833535194397,
#   0.9725000262260437,
#   0.9729999899864197,
#   0.9729166626930237,
#   0.9729166626930237,
#   0.9729166626930237,
#   0.9723333120346069,
#   0.9732499718666077,
#   0.9728333353996277,
#   0.9728333353996277,
#   0.9729166626930237,
#   0.9733333587646484,
#   0.9735000133514404,
#   0.9737499952316284,
#   0.9735833406448364,
#   0.9736666679382324,
#   0.9738333225250244,
#   0.9739166498184204,
#   0.9742500185966492,
#   0.9741666913032532,
#   0.9742500185966492,
#   0.9739166498184204,
#   0.9737499952316284,
#   0.9737499952316284,
#   0.9736666679382324,
#   0.9743333458900452,
#   0.9740833044052124,
#   0.9741666913032532,
#   0.9745000004768372,
#   0.9743333458900452,
#   0.9739166498184204,
#   0.9743333458900452,
#   0.9745000004768372,
#   0.9746666550636292,
#   0.9745000004768372,
#   0.9743333458900452,
#   0.9744166731834412,
#   0.9745833277702332,
#   0.9751666784286499,
#   0.9747499823570251,
#   0.9746666550636292,
#   0.9749166369438171,
#   0.9744166731834412,
#   0.9749166369438171,
#   0.9747499823570251,
#   0.9745000004768372,
#   0.9751666784286499,
#   0.9752500057220459,
#   0.9754166603088379,
#   0.9751666784286499,
#   0.9753333330154419,
#   0.9751666784286499,
#   0.9752500057220459,
#   0.9748333096504211,
#   0.9755833148956299,
#   0.9753333330154419,
#   0.9758333563804626,
#   0.9754166603088379,
#   0.9754166603088379,
#   0.9756666421890259,
#   0.9751666784286499,
#   0.9759166836738586,
#   0.9756666421890259,
#   0.9760833382606506,
#   0.9765833616256714,
#   0.9759166836738586,
#   0.9758333563804626,
#   0.9760833382606506,
#   0.9762499928474426,
#   0.9760833382606506,
#   0.9760833382606506,
#   0.9764166474342346,
#   0.9759166836738586,
#   0.9757500290870667,
#   0.9758333563804626,
#   0.9773333072662354,
#   0.9766666889190674,
#   0.9764999747276306,
#   0.9759166836738586,
#   0.9766666889190674,
#   0.9765833616256714,
#   0.9764166474342346,
#   0.9765833616256714,
#   0.9768333435058594,
#   0.9762499928474426,
#   0.9763333201408386,
#   0.9762499928474426,
#   0.9765833616256714,
#   0.9765833616256714,
#   0.9768333435058594,
#   0.9766666889190674,
#   0.9763333201408386,
#   0.9769166707992554,
#   0.9770833253860474,
#   0.9769166707992554,
#   0.9773333072662354,
#   0.9769166707992554,
#   0.9764999747276306,
#   0.9767500162124634,
#   0.9767500162124634,
#   0.9767500162124634,
#   0.9768333435058594,
#   0.9773333072662354,
#   0.9772499799728394,
#   0.9772499799728394,
#   0.9774166941642761,
#   0.9765833616256714,
#   0.9775000214576721,
#   0.9766666889190674,
#   0.9771666526794434,
#   0.9764999747276306,
#   0.9765833616256714,
#   0.9769999980926514,
#   0.9773333072662354,
#   0.9768333435058594,
#   0.9772499799728394,
#   0.9775833487510681,
#   0.9769999980926514,
#   0.9772499799728394,
#   0.9775000214576721,
#   0.9773333072662354,
#   0.9774166941642761,
#   0.9778333306312561,
#   0.9775833487510681,
#   0.9771666526794434,
#   0.9776666760444641,
#   0.9775000214576721,
#   0.9775000214576721,
#   0.9778333306312561,
#   0.9770833253860474,
#   0.9775000214576721,
#   0.9772499799728394,
#   0.9769166707992554,
#   0.9772499799728394,
#   0.9775833487510681,
#   0.9777500033378601,
#   0.9769999980926514,
#   0.9772499799728394,
#   0.9769166707992554],
#  'loss': [1.6718722133636474,
#   0.8992075864473978,
#   0.683758979956309,
#   0.5846770370006561,
#   0.525754035393397,
#   0.4846093362967173,
#   0.45095719655354816,
#   0.4250658965110779,
#   0.4066349815527598,
#   0.3888261545499166,
#   0.3689992209275564,
#   0.3565222722689311,
#   0.3460938101609548,
#   0.3337863127787908,
#   0.32272762779394787,
#   0.3126862561305364,
#   0.30328299188613894,
#   0.29707930596669513,
#   0.2882234175602595,
#   0.28424983847141266,
#   0.27636587715148925,
#   0.27229393323262535,
#   0.26472316960493725,
#   0.2597511806686719,
#   0.2584855343103409,
#   0.25101329493522645,
#   0.2425371769865354,
#   0.24031073115269344,
#   0.23818535254398981,
#   0.2354887643257777,
#   0.22931666777531307,
#   0.22473954061667126,
#   0.22363058576981226,
#   0.21963726669549943,
#   0.21812078628937404,
#   0.21508833760023116,
#   0.20973961927493412,
#   0.2089105509320895,
#   0.2067344210743904,
#   0.20192610003550848,
#   0.20133131754398345,
#   0.197442391594251,
#   0.1954077922105789,
#   0.19263087328275044,
#   0.19301348110040029,
#   0.18711576068401337,
#   0.18324474883079528,
#   0.18353739873568217,
#   0.1814186001618703,
#   0.1808385282754898,
#   0.18043143474062284,
#   0.17996450672547024,
#   0.17542964530984562,
#   0.17495988535881044,
#   0.16999358701705933,
#   0.1710246942639351,
#   0.16967929166555404,
#   0.16578040849169096,
#   0.16689300194382667,
#   0.1639009438554446,
#   0.15957941029469172,
#   0.1611165189643701,
#   0.1581169713238875,
#   0.15694060337543486,
#   0.15679801674683888,
#   0.15497116895516713,
#   0.1547809205551942,
#   0.15250685479243598,
#   0.15094121143221856,
#   0.151208409935236,
#   0.148521662324667,
#   0.1467129402856032,
#   0.1472895431915919,
#   0.14295105333129565,
#   0.14402254631121952,
#   0.14557483849922817,
#   0.14220314116279284,
#   0.14022393003106118,
#   0.14061547034978866,
#   0.14065883350372316,
#   0.13738761062423388,
#   0.1358161683579286,
#   0.13489491721987723,
#   0.13663298514485359,
#   0.13447861076394718,
#   0.13098290048042932,
#   0.13097946566343308,
#   0.12941854948798814,
#   0.13131663462519647,
#   0.1285410581032435,
#   0.12787239705522854,
#   0.1299058807293574,
#   0.1256942524413268,
#   0.12515774271885555,
#   0.12730577665567397,
#   0.1263186510403951,
#   0.12174668548504511,
#   0.12283007582028707,
#   0.11944881317019462,
#   0.12215305808186531,
#   0.1229182566901048,
#   0.11743703959385554,
#   0.119705665320158,
#   0.11683507142961025,
#   0.1174767566372951,
#   0.1143974838455518,
#   0.11542057522634665,
#   0.11316583225131036,
#   0.11293486032883326,
#   0.11509303732713064,
#   0.11660770687957604,
#   0.11234165783723195,
#   0.112706650664409,
#   0.11186664322018623,
#   0.11055477420488993,
#   0.11099348080158233,
#   0.10879751584927241,
#   0.10865701960523923,
#   0.10822419410943986,
#   0.1066157892694076,
#   0.10832147735357285,
#   0.10390481857955455,
#   0.1061399976114432,
#   0.10567533836762111,
#   0.10591114595532418,
#   0.10494920891523361,
#   0.10436182590325674,
#   0.10409288234512011,
#   0.10528836751977602,
#   0.10376010650396347,
#   0.10161979921658834,
#   0.10025311340888342,
#   0.09912813422083855,
#   0.10144342001279195,
#   0.09871464263647795,
#   0.0971934193422397,
#   0.09625182654460271,
#   0.0979212400764227,
#   0.09941119007766247,
#   0.09649601362148921,
#   0.09714528621236483,
#   0.09605762114624182,
#   0.09550403873125712,
#   0.0929778832346201,
#   0.0933005146831274,
#   0.09484709826608499,
#   0.09463901118934155,
#   0.09536252125104268,
#   0.09287844583888849,
#   0.09252023696402709,
#   0.09237083211541176,
#   0.09379832968115806,
#   0.09071931028862794,
#   0.09068792542815209,
#   0.0906665573467811,
#   0.08920762491722901,
#   0.08905718411008517,
#   0.08797566772003969,
#   0.08757262125611305,
#   0.08656840939323107,
#   0.08869213685890039,
#   0.08717559082309405,
#   0.08742000564436118,
#   0.08584114600718021,
#   0.08685220082104206,
#   0.08815349231660366,
#   0.0866272531747818,
#   0.08486220383395751,
#   0.0844598376105229,
#   0.0855181660403808,
#   0.08645889274775982,
#   0.0833883265554905,
#   0.08563760234912236,
#   0.08452908683816591,
#   0.08594685267905394,
#   0.08299352122346561,
#   0.08228781862556935,
#   0.08202325454105934,
#   0.08033563554783663,
#   0.08199699421226979,
#   0.08107089652121068,
#   0.08044467855244875,
#   0.08036414330204328,
#   0.08196108164886634,
#   0.07945034506420294,
#   0.07820535088082155,
#   0.07795571701228618,
#   0.07788306624690691,
#   0.08017335980633894,
#   0.0783656632527709,
#   0.07476238685846329,
#   0.07687020907799402,
#   0.07942780070006847,
#   0.07643195123473803,
#   0.07532043168942133,
#   0.07512830511977275,
#   0.07538412436346213,
#   0.0780446699783206,
#   0.07379948956767718,
#   0.07616352656980356,
#   0.07439504619936148,
#   0.07241702577720086,
#   0.07213199892888467,
#   0.07546354597061873,
#   0.07496590634932121,
#   0.07570569114387035,
#   0.07286426049967606,
#   0.07110995235542457,
#   0.07311770387987296,
#   0.07363068788250288,
#   0.0741514995098114,
#   0.07375964750349522,
#   0.07156639288862546,
#   0.0727189914509654,
#   0.07116568032403787,
#   0.07122272138794263,
#   0.07130595603585244,
#   0.06955583822975556,
#   0.07329069668302933,
#   0.07002548058331012,
#   0.07008433881898721,
#   0.07142518803477288,
#   0.0700193481867512,
#   0.0680681583210826,
#   0.07010175874332587,
#   0.06845714927713076,
#   0.06856252852082252,
#   0.06837873048832019,
#   0.06697360224028429,
#   0.06707507400214673,
#   0.06727642894039551,
#   0.06658514550328255,
#   0.06505235465615988,
#   0.06693866175413132,
#   0.06733325602610905,
#   0.0663282455901305,
#   0.06523035867015521,
#   0.06557061164329449,
#   0.06602629491190115,
#   0.06615507517258326,
#   0.0649811389297247,
#   0.06631172414372365,
#   0.06441112239658832,
#   0.06355551739782095,
#   0.06432605893413226,
#   0.06555197340995074,
#   0.06320356309662263,
#   0.06264182985574007,
#   0.0638159208148718,
#   0.06376772858202458],
#  'accuracy': [0.46670833,
#   0.7242708,
#   0.79141665,
#   0.8205625,
#   0.84141666,
#   0.85802084,
#   0.8670625,
#   0.87335414,
#   0.87916666,
#   0.88570833,
#   0.890875,
#   0.89472914,
#   0.89825,
#   0.9022292,
#   0.90489584,
#   0.907875,
#   0.91183335,
#   0.91170835,
#   0.91529167,
#   0.9170833,
#   0.91789585,
#   0.91897917,
#   0.92225,
#   0.9225417,
#   0.9246042,
#   0.92679167,
#   0.9297708,
#   0.9295625,
#   0.93008333,
#   0.930375,
#   0.93291664,
#   0.93308336,
#   0.9338958,
#   0.9345833,
#   0.93583333,
#   0.93689585,
#   0.937625,
#   0.93766665,
#   0.9392292,
#   0.94016665,
#   0.94075,
#   0.9412917,
#   0.9421875,
#   0.9430625,
#   0.9426875,
#   0.94472915,
#   0.94535416,
#   0.9450625,
#   0.9465,
#   0.94602084,
#   0.9459792,
#   0.94560415,
#   0.94825,
#   0.94783336,
#   0.9502083,
#   0.94872916,
#   0.95014584,
#   0.9506458,
#   0.95002085,
#   0.9517083,
#   0.9524375,
#   0.95185417,
#   0.95370835,
#   0.9537708,
#   0.9537708,
#   0.95435417,
#   0.9538958,
#   0.95435417,
#   0.954625,
#   0.9556875,
#   0.9566875,
#   0.9561875,
#   0.95566666,
#   0.95677084,
#   0.95708334,
#   0.9569167,
#   0.9571458,
#   0.9584375,
#   0.957375,
#   0.9580208,
#   0.9588125,
#   0.9590833,
#   0.959625,
#   0.959,
#   0.95935416,
#   0.96022916,
#   0.9601875,
#   0.96108335,
#   0.96020836,
#   0.96110415,
#   0.96089584,
#   0.960625,
#   0.962625,
#   0.96239585,
#   0.962125,
#   0.96254164,
#   0.9633125,
#   0.96272916,
#   0.964,
#   0.9632292,
#   0.9633333,
#   0.96477085,
#   0.9636875,
#   0.9658333,
#   0.9649792,
#   0.9658125,
#   0.96477085,
#   0.96608335,
#   0.9662708,
#   0.9655625,
#   0.96477085,
#   0.9668125,
#   0.9659167,
#   0.96620834,
#   0.96641666,
#   0.96585417,
#   0.967,
#   0.966875,
#   0.9672083,
#   0.9668958,
#   0.96695834,
#   0.96835417,
#   0.9685,
#   0.96847916,
#   0.9680833,
#   0.96814585,
#   0.96827084,
#   0.96847916,
#   0.96877086,
#   0.96802086,
#   0.96991664,
#   0.96914583,
#   0.9698125,
#   0.96920836,
#   0.969,
#   0.97064584,
#   0.97079164,
#   0.97066665,
#   0.96958333,
#   0.9713542,
#   0.97052085,
#   0.97083336,
#   0.97066665,
#   0.971,
#   0.9709375,
#   0.9713125,
#   0.9710625,
#   0.9704583,
#   0.97125,
#   0.971375,
#   0.9721875,
#   0.97154164,
#   0.97229165,
#   0.97216666,
#   0.97258335,
#   0.97314584,
#   0.97241664,
#   0.97272915,
#   0.9729375,
#   0.9739583,
#   0.97172916,
#   0.97370833,
#   0.973375,
#   0.9733958,
#   0.972375,
#   0.9732917,
#   0.9726667,
#   0.973625,
#   0.9735417,
#   0.973375,
#   0.9730833,
#   0.97445834,
#   0.97445834,
#   0.97335416,
#   0.9733125,
#   0.97391665,
#   0.97479165,
#   0.97464585,
#   0.9756875,
#   0.9753542,
#   0.975125,
#   0.97433335,
#   0.975375,
#   0.97510415,
#   0.97541666,
#   0.975375,
#   0.97577083,
#   0.97554165,
#   0.9754583,
#   0.9760417,
#   0.976875,
#   0.9759167,
#   0.97564584,
#   0.9759167,
#   0.97727084,
#   0.9759167,
#   0.9762292,
#   0.9750625,
#   0.9765,
#   0.9762083,
#   0.9764583,
#   0.9780833,
#   0.9779792,
#   0.97695833,
#   0.97716665,
#   0.97725,
#   0.97683334,
#   0.97727084,
#   0.97685415,
#   0.9773125,
#   0.9765,
#   0.976625,
#   0.9766875,
#   0.9775208,
#   0.9773125,
#   0.977,
#   0.9781875,
#   0.97802085,
#   0.9770833,
#   0.97783333,
#   0.978125,
#   0.97760415,
#   0.9785417,
#   0.977875,
#   0.9780833,
#   0.97816664,
#   0.978875,
#   0.9782708,
#   0.97975,
#   0.979375,
#   0.9788542,
#   0.9787083,
#   0.979375,
#   0.97891665,
#   0.97889584,
#   0.9797083,
#   0.97989583,
#   0.9796042,
#   0.97889584,
#   0.9798333,
#   0.97902083,
#   0.979375,
#   0.9794375,
#   0.9793958,
#   0.9799375,
#   0.9791458,
#   0.980125,
#   0.9807917,
#   0.9799375,
#   0.9803125]}

# %% [markdown]
# # Multilayer Perceptron - Versão 4

# %% [markdown]
# Testando outros otimizadores

# %% [markdown]
# https://keras.io/optimizers

# %% [markdown]
# Uma rede neural é essencialmente uma composição de múltiplas funções com milhares, e às vezes milhões, de parâmetros. Cada camada de rede calcula uma função cujo erro deve ser minimizado para melhorar a precisão observada durante a fase de aprendizagem.

# %% [markdown]
# Keras implementa uma variante rápida de descida de gradiente conhecida como descida de gradiente estocástica (SGD) e duas técnicas de otimização mais avançadas conhecidas como RMSprop e Adam. RMSprop e Adam incluem o conceito de momentum (uma componente de velocidade) além da componente de aceleração que tem SGD. Isso permite uma convergência mais rápida ao custo de mais computação. SGD foi nossa escolha padrão até agora. Então vamos tentar os outros dois. É muito simples, só precisamos mudar algumas linhas.

# %%
# Import dos pacotes e funções
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import RMSprop, Adam
from keras.utils import np_utils
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Garantindo que o resultado pode ser reproduzido
np.random.seed(1671)

# %%
# Parâmetros da rede e do treinamento
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10   # número de outputs = número de dígitos
#OPTIMIZER = RMSprop() # otimizador
OPTIMIZER = Adam() # otimizador
N_HIDDEN = 128
VALIDATION_SPLIT=0.2 # quanto é reservado para validação
DROPOUT = 0.3

# %%
# Gerando datasets de treino e teste
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# X_train possui 60000 linhas de valores 28x28 --> reshape para 60000 x 784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# Normalizando os dados
# Tipicamente, os valores associados a cada pixel são normalizados na faixa [0, 1] 
# (o que significa que a intensidade de cada pixel é dividida por 255, o valor de intensidade máxima). 
# A saída é 10 classes, uma para cada dígito.
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'exemplos de treinamento')
print(X_test.shape[0], 'exemplos de teste')
# Out:
# 60000 exemplos de treinamento
# 10000 exemplos de teste

# %%
# Converte os vetores da class para matrizes binárias das classes
Y_train = np_utils.to_categorical(y_train, NB_CLASSES)
Y_test = np_utils.to_categorical(y_test, NB_CLASSES)

# %%
# Cria as camadas 
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape = (RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

# %%
# Sumário da rede
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 128)               100480
# _________________________________________________________________
# activation_8 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_9 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_10 (Activation)   (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compila o modelo
model.compile(loss = 'categorical_crossentropy', optimizer = OPTIMIZER, metrics = ['accuracy'])

# %%
# Treinamento do modelo
modelo_v4 = model.fit(X_train, Y_train,
                      batch_size = BATCH_SIZE, 
                      epochs = NB_EPOCH,
                      verbose = VERBOSE, 
                      validation_split = VALIDATION_SPLIT)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/20
# 48000/48000 [==============================] - 1s 18us/step - loss: 0.5141 - accuracy: 0.8422 - val_loss: 0.1823 - val_accuracy: 0.9476
# Epoch 2/20
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.2316 - accuracy: 0.9315 - val_loss: 0.1348 - val_accuracy: 0.9607
# Epoch 3/20
# 48000/48000 [==============================] - 1s 16us/step - loss: 0.1739 - accuracy: 0.9478 - val_loss: 0.1098 - val_accuracy: 0.9667
# Epoch 4/20
# 48000/48000 [==============================] - 1s 18us/step - loss: 0.1472 - accuracy: 0.9562 - val_loss: 0.1018 - val_accuracy: 0.9692
# Epoch 5/20
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1308 - accuracy: 0.9607 - val_loss: 0.0976 - val_accuracy: 0.9705
# Epoch 6/20
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.1177 - accuracy: 0.9643 - val_loss: 0.0878 - val_accuracy: 0.9734
# Epoch 7/20
# 48000/48000 [==============================] - 1s 15us/step - loss: 0.1039 - accuracy: 0.9675 - val_loss: 0.0864 - val_accuracy: 0.9739
# Epoch 8/20
# 48000/48000 [==============================] - 1s 16us/step - loss: 0.0968 - accuracy: 0.9691 - val_loss: 0.0873 - val_accuracy: 0.9747
# Epoch 9/20
# 48000/48000 [==============================] - 1s 15us/step - loss: 0.0889 - accuracy: 0.9724 - val_loss: 0.0849 - val_accuracy: 0.9750
# Epoch 10/20
# 48000/48000 [==============================] - 1s 16us/step - loss: 0.0824 - accuracy: 0.9742 - val_loss: 0.0833 - val_accuracy: 0.9757
# Epoch 11/20
# 48000/48000 [==============================] - 1s 17us/step - loss: 0.0780 - accuracy: 0.9759 - val_loss: 0.0819 - val_accuracy: 0.9769
# Epoch 12/20
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.0711 - accuracy: 0.9772 - val_loss: 0.0837 - val_accuracy: 0.9767
# Epoch 13/20
# 48000/48000 [==============================] - 1s 15us/step - loss: 0.0703 - accuracy: 0.9774 - val_loss: 0.0844 - val_accuracy: 0.9765
# Epoch 14/20
# 48000/48000 [==============================] - 1s 15us/step - loss: 0.0665 - accuracy: 0.9783 - val_loss: 0.0874 - val_accuracy: 0.9766
# Epoch 15/20
# 48000/48000 [==============================] - 1s 16us/step - loss: 0.0677 - accuracy: 0.9777 - val_loss: 0.0865 - val_accuracy: 0.9763
# Epoch 16/20
# 48000/48000 [==============================] - 1s 16us/step - loss: 0.0613 - accuracy: 0.9799 - val_loss: 0.0845 - val_accuracy: 0.9765
# Epoch 17/20
# 48000/48000 [==============================] - 1s 14us/step - loss: 0.0579 - accuracy: 0.9815 - val_loss: 0.0851 - val_accuracy: 0.9768
# Epoch 18/20
# 48000/48000 [==============================] - 1s 15us/step - loss: 0.0560 - accuracy: 0.9811 - val_loss: 0.0891 - val_accuracy: 0.9768
# Epoch 19/20
# 48000/48000 [==============================] - 1s 18us/step - loss: 0.0538 - accuracy: 0.9827 - val_loss: 0.0913 - val_accuracy: 0.9764
# Epoch 20/20
# 48000/48000 [==============================] - 1s 15us/step - loss: 0.0514 - accuracy: 0.9831 - val_loss: 0.0918 - val_accuracy: 0.9770

# %%
# Testa o modelo e imprime o score
score = model.evaluate(X_test, Y_test, verbose = VERBOSE)
print("\nTest score:", score[0])
print('Test accuracy:', score[1])
# Out:
# 10000/10000 [==============================] - 0s 13us/step
#
# Test score: 0.0773961384162154
# Test accuracy: 0.9805999994277954

# %%
# Imprime os dados no modelo
print(modelo_v4.history.keys())

# Sumariza o modelo para acurácia
plt.plot(modelo_v4.history['accuracy'])
plt.plot(modelo_v4.history['val_accuracy'])
plt.title('Acurácia do Modelo')
plt.ylabel('Acurácia')
plt.xlabel('Epoch')
plt.legend(['Treino', 'Teste'], loc = 'lower right')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
# Imprime a evolução de erro do modelo
plt.plot(modelo_v4.history['loss'])
plt.plot(modelo_v4.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Treino', 'Teste'], loc='upper right')
plt.show()

# %% [markdown]
# ## Fim
